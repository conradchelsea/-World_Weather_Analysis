# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("/Users/chelseaconrad/Desktop/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    City_ID     City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        0   albany      US  42.60  -73.97     48.99        42           0
# 1        1  ushuaia      AR -54.80  -68.30     51.80        50          40
# 2        2  college      US  64.86 -147.80     30.00        85          75
# 3        3   hobart      AU -42.88  147.33     44.60        81          75
# 4        4  klyuchi      RU  52.27   79.17     38.71        82         100
#
#    Wind Speed Current Description
# 0        5.39           clear sky
# 1        3.36    scattered clouds
# 2        3.42       broken clouds
# 3        6.93       broken clouds
# 4       15.19          light rain

# %%
city_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City_ID              689 non-null    int64
#  1   City                 689 non-null    object
#  2   Country              682 non-null    object
#  3   Lat                  689 non-null    float64
#  4   Lng                  689 non-null    float64
#  5   Max Temp             689 non-null    float64
#  6   Humidity             689 non-null    int64
#  7   Cloudiness           689 non-null    int64
#  8   Wind Speed           689 non-null    float64
#  9   Current Description  689 non-null    object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 54.0+ KB

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
# Ask the customer to add a minimum and maximum temperature value. My code ex from module.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))

# min_temp = 75
# max_temp = 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
# Filter the dataset to find the cities that fit the criteria. My code ex from module. 
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID          City Country    Lat     Lng  Max Temp  Humidity  \
# 10       10          hilo      US  19.73 -155.09     82.40        74
# 11       11     boyolangu      ID  -8.12  111.89     75.70        90
# 13       13  puerto ayora      EC  -0.74  -90.35     78.80        69
# 19       19    georgetown      MY   5.41  100.34     77.00        94
# 23       23          miri      MY   4.41  114.01     77.00        94
# 27       27        faanui      PF -16.48 -151.75     80.02        69
# 29       29    butaritari      KI   3.07  172.79     81.09        70
# 35       35        sabang      ID   5.89   95.32     81.75        75
# 43       43    quang ngai      VN  15.12  108.80     75.63        92
# 49       49       kahului      US  20.89 -156.47     87.80        52
#
#     Cloudiness  Wind Speed Current Description
# 10          40        5.82    scattered clouds
# 11         100        2.39     overcast clouds
# 13          40       20.80    scattered clouds
# ...

# %%
# 4a. Determine if there are any empty rows. 
#My examples from module, any should work.
#preferred_cities_df.count()
preferred_cities_df.notnull().sum()
#preferred_cities_df.isnull().sum()
# Out:
# City_ID                189
# City                   189
# Country                188
# Lat                    189
# Lng                    189
# Max Temp               189
# Humidity               189
# Cloudiness             189
# Wind Speed             189
# Current Description    189
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
preferred_cities_df_2 = preferred_cities_df.dropna()
preferred_cities_df_2.notnull().sum()
preferred_cities_df_2.info()
preferred_cities_df_2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 188 entries, 10 to 686
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City_ID              188 non-null    int64
#  1   City                 188 non-null    object
#  2   Country              188 non-null    object
#  3   Lat                  188 non-null    float64
#  4   Lng                  188 non-null    float64
#  5   Max Temp             188 non-null    float64
#  6   Humidity             188 non-null    int64
#  7   Cloudiness           188 non-null    int64
#  8   Wind Speed           188 non-null    float64
#  9   Current Description  188 non-null    object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 16.2+ KB
#     City_ID          City Country    Lat     Lng  Max Temp  Humidity  \
# 10       10          hilo      US  19.73 -155.09      82.4        74
# ...

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
#hotel_df = clean_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
#hotel_df["Hotel Name"] = ""
#hotel_df.head(10)

# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates. From module
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = "Hotel Name"
hotel_df.head(10)
# Out:
#             City Country  Max Temp Current Description    Lat     Lng  \
# 10          hilo      US     82.40    scattered clouds  19.73 -155.09
# 11     boyolangu      ID     75.70     overcast clouds  -8.12  111.89
# 13  puerto ayora      EC     78.80    scattered clouds  -0.74  -90.35
# 19    georgetown      MY     77.00    scattered clouds   5.41  100.34
# 23          miri      MY     77.00    scattered clouds   4.41  114.01
# 27        faanui      PF     80.02           clear sky -16.48 -151.75
# 29    butaritari      KI     81.09       broken clouds   3.07  172.79
# 35        sabang      ID     81.75     overcast clouds   5.89   95.32
# 43    quang ngai      VN     75.63     overcast clouds  15.12  108.80
# 49       kahului      US     87.80          few clouds  20.89 -156.47
#
#     Hotel Name
# 10  Hotel Name
# 11  Hotel Name
# 13  Hotel Name
# 19  Hotel Name
# 23  Hotel Name
# 27  Hotel Name
# 29  Hotel Name
# 35  Hotel Name
# 43  Hotel Name
# 49  Hotel Name

# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key


# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # 6c. Get latitude and longitude from DataFrame
    
    print("trying request")
    
    # 6e. Make request and retrieve the JSON data from the search. 
    # Make request and get the JSON data from the search.
    print(base_url, params)
    try:
        hotels = requests.get(base_url, params=params).json()
        print("tried request")
        print(hotels.keys())
        #print(hotels)
        # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
        # Grab the first hotel from the results and store the name.
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except(IndexError):
        print("index error ", params )
        pass
# Out:
# trying request
# https://maps.googleapis.com/maps/api/place/nearbysearch/json {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyDhvrIWx2-Va170yu-VZyXVMcy-Nzl1RcI', 'location': '19.73,-155.09'}
# tried request
# dict_keys(['html_attributions', 'next_page_token', 'results', 'status'])
# trying request
# https://maps.googleapis.com/maps/api/place/nearbysearch/json {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyDhvrIWx2-Va170yu-VZyXVMcy-Nzl1RcI', 'location': '-8.12,111.89'}
# tried request
# dict_keys(['html_attributions', 'next_page_token', 'results', 'status'])
# trying request
# https://maps.googleapis.com/maps/api/place/nearbysearch/json {'radius': 5000, 'type': 'lodging', 'key': 'AIzaSyDhvrIWx2-Va170yu-VZyXVMcy-Nzl1RcI', 'location': '-0.74,-90.35'}
# tried request
# dict_keys(['html_attributions', 'next_page_token', 'results', 'status'])
# trying request
# ...

# %%
hotel_df.info()
hotel_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 189 entries, 10 to 686
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   City                 189 non-null    object
#  1   Country              188 non-null    object
#  2   Max Temp             189 non-null    float64
#  3   Current Description  189 non-null    object
#  4   Lat                  189 non-null    float64
#  5   Lng                  189 non-null    float64
#  6   Hotel Name           189 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 16.8+ KB
#             City Country  Max Temp Current Description    Lat     Lng  \
# 10          hilo      US     82.40    scattered clouds  19.73 -155.09
# 11     boyolangu      ID     75.70     overcast clouds  -8.12  111.89
# 13  puerto ayora      EC     78.80    scattered clouds  -0.74  -90.35
# 19    georgetown      MY     77.00    scattered clouds   5.41  100.34
# ...

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df["Hotel Name"].isna()
# Out:
# 10     False
# 11     False
# 13     False
# 19     False
# 23     False
#        ...
# 670    False
# 673    False
# 679    False
# 681    False
# 686    False
# Name: Hotel Name, Length: 189, dtype: bool

# %%
# 7. Drop the rows where there is no Hotel Name.
# hotel_df["Hotel Name"].isnull()
clean_hotel_df = hotel_df
clean_hotel_df["Hotel Name"] = hotel_df["Hotel Name"].dropna()

# %%
clean_hotel_df
# Out:
#              City Country  Max Temp Current Description    Lat     Lng  \
# 10           hilo      US     82.40    scattered clouds  19.73 -155.09
# 11      boyolangu      ID     75.70     overcast clouds  -8.12  111.89
# 13   puerto ayora      EC     78.80    scattered clouds  -0.74  -90.35
# 19     georgetown      MY     77.00    scattered clouds   5.41  100.34
# 23           miri      MY     77.00    scattered clouds   4.41  114.01
# ..            ...     ...       ...                 ...    ...     ...
# 670  saint simons      US     80.60           clear sky  31.14  -81.39
# 673       haapiti      PF     82.40         shower rain -17.57 -149.87
# 679        hwange      ZW     75.31           clear sky -18.37   26.50
# 681    port blair      IN     79.20       moderate rain  11.67   92.75
# 686       liberty      US     84.99    scattered clouds  31.83  -81.50
#
#                                   Hotel Name
# 10                       Hilo Hawaiian Hotel
# ...

# %%
# 8a. Create the output File (CSV)
output_data_file = "/Users/chelseaconrad/Desktop/World_Weather_Analysis/Weather_Database/WeatherPy_vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
#<dt>Current Description</dt><dd>{Current Description}</dd>
info_box_template = """
<dl>
<dt><b>Hotel Name</b></dt><dd>{Hotel Name}</dd>
<dt><b>City</b></dt><dd>{City}</dd>
<dt><b>Country</b></dt><dd>{Country}</dd>
<dt><b>Current Weather</b></dt><dd>{Current Description}</dd>
<dt><b>Max Temp</b></dt><dd>{Max Temp} °F</dd>
</dl>
"""
# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# print(locations[1][1])
locations
# Out:
#        Lat     Lng
# 10   19.73 -155.09
# 11   -8.12  111.89
# 13   -0.74  -90.35
# 19    5.41  100.34
# 23    4.41  114.01
# ..     ...     ...
# 670  31.14  -81.39
# 673 -17.57 -149.87
# 679 -18.37   26.50
# 681  11.67   92.75
# 686  31.83  -81.50
#
# [189 rows x 2 columns]

# %%
# 11a. Add a marker layer for each city to the map. 

# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
max_temp = clean_hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# 11b. Display the figure
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-03d80d0061c3> in <module>
#       2
#       3 # Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
# ----> 4 max_temp = clean_hotel_df["Max Temp"]
#       5 fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
#       6 heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
#
# NameError: name 'clean_hotel_df' is not defined

# %%
# max_temp = clean_hotel_df["Max Temp"]
# max_temp
# Out:
# 10     82.40
# 11     75.70
# 13     78.80
# 19     77.00
# 23     77.00
#        ...
# 670    80.60
# 673    82.40
# 679    75.31
# 681    79.20
# 686    84.99
# Name: Max Temp, Length: 189, dtype: float64

# %%
# import gmaps

# # Import API key
# from config import g_key

# # Configure gmaps API key
# gmaps.configure(api_key=g_key)

# # Add a heatmap of temperature for the vacation spots.
# locations = clean_hotel_df[["Lat", "Lng"]]
# max_temp = clean_hotel_df["Max Temp"]
# fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
#              max_intensity=300, point_radius=4)

# fig.add_layer(heat_layer)
# # Call the figure to plot the data.
# fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
