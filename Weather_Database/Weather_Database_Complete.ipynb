# -19.398306045723885 32.43377405542975
# -48.66384139808108 -20.16343281707043
# -83.27543294468865 174.19190827286985
# -39.060273496823044 -78.22174883186528
# -73.23076310410949 -13.064304042656374
# 78.39611181527658 -33.11658658626743
# -15.416104846403613 -86.82717510092252
# -33.88056368707153 150.90027695187024
# 18.16013382815143 -80.23934903910714
# -0.7306970497166105 -130.6288284478158
# 15.015137962190977 -103.98727235444291
# -74.3849594192499 125.98252652870792
# -56.186646113571165 170.0495936604524
# -53.067919087424016 13.22370130907882
# 52.0208719271337 -137.1191315601773
# -75.29502958339235 -81.17014782836301
# -18.953715010409525 27.799626980066336
# 44.60478523852649 -54.246196134718645
# -3.172249544980218 -16.350376042102653
# -13.261120683337495 -71.54922395449817
# 9.030679435566412 -12.825614616279267
# -81.14072510082651 100.04728788033918
# -56.04006665676429 -131.30531376019582
# 68.55781269807568 126.18491578620069
# 15.145735085132458 46.3447270753322
# -16.34808876531136 -25.663936390067875
# -77.77726454152581 -127.16680872847594
# -0.5019884124894531 88.49175100116463
# -16.294671522489466 61.02217813466973
# 11.450800105300104 -170.2075223649244
# -49.34403721708485 17.726870731920542
# 23.22265207981806 -130.2023832567327
# 58.70573902637048 -96.4299479765907
# 24.325336479365717 -60.30569393343562
# 7.65126851676996 72.33154154887401
# -29.503042681258584 -129.04610724321896
# -57.416303721530554 -10.291530188217735
# -31.719108157503335 -44.95048590708225

# %%
coordinates = lat_lngs
lat_lngs
# coordinates

# %%
# Create a set of random latitude and longitude combinations.
# lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
# lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = lat_lngs

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
len(cities)
cities
# Out:
# ['albany',
#  'ushuaia',
#  'college',
#  'hobart',
#  'klyuchi',
#  'katra',
#  'hermanus',
#  'shimoda',
#  'vaitupu',
#  'yugorsk',
#  'nizhneyansk',
#  'bengkulu',
#  'hilo',
#  'boyolangu',
#  'vila',
#  'puerto ayora',
#  'rikitea',
#  'le port',
#  'hualmay',
#  'ponta do sol',
#  'saleaula',
#  'lolua',
#  'nanortalik',
#  'georgetown',
#  'ukiah',
#  'busselton',
#  'mataura',
#  'miri',
#  'vaini',
#  'puerto del rosario',
#  'nemuro',
#  'faanui',
#  'we',
#  'fuxin',
#  'butaritari',
#  'danjiangkou',
#  'belushya guba',
#  'mar del plata',
#  'kruisfontein',
#  'dongsheng',
#  'punta arenas',
#  'sabang',
#  'kamenka',
#  'fortuna',
#  'awbari',
#  'xichang',
#  'raton',
#  'longyearbyen',
#  'tiksi',
#  'quang ngai',
#  'marcona',
#  'geraldton',
#  'nikolskoye',
#  'san quintin',
#  'havre-saint-pierre',
#  'bethel',
#  'kahului',
#  'mys shmidta',
#  'cape town',
#  'beroroha',
#  'mahebourg',
#  'chokurdakh',
#  'souillac',
#  'iqaluit',
#  'qasigiannguit',
#  'bluff',
#  'sola',
#  'portland',
#  'saint-ambroise',
#  'mount gambier',
#  'tunduru',
#  'berlevag',
#  'jamestown',
#  'leningradskiy',
#  'marsa matruh',
#  'halifax',
#  'saint-philippe',
#  'hithadhoo',
#  'olafsvik',
#  'hamilton',
#  'eldorado',
#  'avarua',
#  'kodiak',
#  'vestmannaeyjar',
#  'kandrian',
#  'yanan',
#  'nuuk',
#  'sitka',
#  'plattsburgh',
#  'presidencia roque saenz pena',
#  'lyubim',
#  'uthal',
#  'nouadhibou',
#  'shenjiamen',
#  'bulungu',
#  'narsaq',
#  'khatanga',
#  'port lincoln',
#  'kanniyakumari',
#  'nova russas',
#  'potiskum',
#  'guerrero negro',
#  'zychlin',
#  'yellowknife',
#  'kawalu',
#  'oceanside',
#  'spornoye',
#  'burnie',
#  'carutapera',
#  'tynda',
#  'cabo san lucas',
#  'husavik',
#  'touros',
#  'norman wells',
#  'pumiao',
#  'barrow',
#  'klaksvik',
#  'lieksa',
#  'durban',
#  'saldanha',
#  'cockburn town',
#  'port alfred',
#  'moerai',
#  'monkey bay',
#  'cidreira',
#  'taolanaro',
#  'suluq',
#  'sept-iles',
#  'parrita',
#  'sinnamary',
#  'mogocha',
#  'bredasdorp',
#  'madison',
#  'lesozavodsk',
#  'labuhan',
#  'upernavik',
#  'bereda',
#  'tuatapere',
#  'buzmeyin',
#  'vila velha',
#  'katherine',
#  'attawapiskat',
#  'provideniya',
#  'atuona',
#  'erenhot',
#  'bambous virieux',
#  'ca mau',
#  'kuryk',
#  'pozo colorado',
#  'sur',
#  'cherskiy',
#  'ngukurr',
#  'vao',
#  'tuktoyaktuk',
#  'coolum beach',
#  'mount isa',
#  'pochutla',
#  'pisco',
#  'port said',
#  'honiara',
#  'saskylakh',
#  'mayumba',
#  'bokspits',
#  'vostok',
#  'goure',
#  'beringovskiy',
#  'zhigansk',
#  'hofn',
#  'illoqqortoormiut',
#  'fukue',
#  'hami',
#  'tacuarembo',
#  'port elizabeth',
#  'lagoa',
#  'aripuana',
#  'antofagasta',
#  'senador guiomard',
#  'sapele',
#  'opuwo',
#  'kloulklubed',
#  'nara',
#  'barinas',
#  'bentiu',
#  'coquimbo',
#  'vila franca do campo',
#  'coihaique',
#  'helong',
#  'alyangula',
#  'cheuskiny',
#  'thompson',
#  'bambanglipuro',
#  'talnakh',
#  'san patricio',
#  'torbay',
#  'carnarvon',
#  'kapaa',
#  'orlik',
#  'altay',
#  'myitkyina',
#  'port hedland',
#  'new norfolk',
#  'lavrentiya',
#  'hukuntsi',
#  'mopti',
#  'san cristobal',
#  'kalmunai',
#  'dudinka',
#  'sheopur',
#  'nadym',
#  'yakeshi',
#  'dikson',
#  'hilton head island',
#  'sao joao da barra',
#  'vardo',
#  'halalo',
#  'arraial do cabo',
#  'luderitz',
#  'sheltozero',
#  'castro',
#  'pekan',
#  'anadyr',
#  'port macquarie',
#  'salalah',
#  'bireun',
#  'california city',
#  'isangel',
#  'alim',
#  'ekhabi',
#  'isiro',
#  'rio gallegos',
#  'murgab',
#  'nivala',
#  'zheleznodorozhnyy',
#  'los llanos de aridane',
#  'koumac',
#  'walvis bay',
#  'fort nelson',
#  'namibe',
#  'chinhoyi',
#  'kaitangata',
#  'othonoi',
#  'pevek',
#  'soyo',
#  'kaman',
#  'viedma',
#  'fuengirola',
#  'yerbogachen',
#  'kaeo',
#  'krasnoselkup',
#  'panguna',
#  'davila',
#  'aswan',
#  'terekli-mekteb',
#  'iwanai',
#  'barentsburg',
#  'tevriz',
#  'svetlogorsk',
#  'papillion',
#  'oktyabrskoye',
#  'chuy',
#  'jenbach',
#  'darhan',
#  'funadhoo',
#  'faya',
#  'ancud',
#  'chimore',
#  'taos',
#  'krasnyy luch',
#  'lebu',
#  'rawson',
#  'simpang',
#  'ta khmau',
#  'ewa beach',
#  'mazyr',
#  'augustow',
#  'whitehaven',
#  'almaznyy',
#  'maghama',
#  'clyde river',
#  'kununurra',
#  'dunmore town',
#  'victoria',
#  'bulawayo',
#  'gorontalo',
#  'mehamn',
#  'kabare',
#  'nicoya',
#  'macaboboni',
#  'gold coast',
#  'trairi',
#  'tumannyy',
#  'broome',
#  'hasaki',
#  'bardiyah',
#  'araouane',
#  'kushmurun',
#  'saint-augustin',
#  'tasiilaq',
#  'menongue',
#  'ugoofaaru',
#  'cap-aux-meules',
#  'bolungarvik',
#  'akureyri',
#  'yar-sale',
#  'auki',
#  'raga',
#  'sedalia',
#  'concordia',
#  'lekoni',
#  'ilulissat',
#  'searcy',
#  'aitape',
#  'ostersund',
#  'tsihombe',
#  'deputatskiy',
#  'grants',
#  'rorvik',
#  'sovetskoye',
#  'turbat',
#  'constitucion',
#  'sao filipe',
#  'alofi',
#  'adrar',
#  'bathsheba',
#  'bac lieu',
#  'khuzdar',
#  'thinadhoo',
#  'novopskov',
#  'comodoro rivadavia',
#  'east london',
#  'mendahara',
#  'cutervo',
#  'yarmouth',
#  'diu',
#  'tidore',
#  'sisimiut',
#  'qaanaaq',
#  'bud',
#  'port-cartier',
#  'makushino',
#  'pandan',
#  'falealupo',
#  'ruatoria',
#  'la motte-servolex',
#  'hobyo',
#  'flinders',
#  'tamboril',
#  'samsun',
#  'paracatu',
#  'yeppoon',
#  'trabzon',
#  'beloha',
#  'buchanan',
#  'zaysan',
#  'esperance',
#  'karaul',
#  'tarragona',
#  'balclutha',
#  'cedar city',
#  'yakymivka',
#  'hovd',
#  'mgandu',
#  'viransehir',
#  'yulara',
#  'virginia beach',
#  'ulaanbaatar',
#  'kaitong',
#  'imbituba',
#  'ofunato',
#  'royan',
#  'axim',
#  'lockport',
#  'kavieng',
#  'naze',
#  'aksha',
#  'salinopolis',
#  'khani',
#  'tres lagoas',
#  'kangaba',
#  'amderma',
#  'louisbourg',
#  'nome',
#  'sovetskiy',
#  'halmstad',
#  'katsuura',
#  'nantucket',
#  'aksarka',
#  'cayenne',
#  'samarai',
#  'makakilo city',
#  'codrington',
#  'mildura',
#  'ryde',
#  'balikpapan',
#  'butiama',
#  'port hawkesbury',
#  'hamamatsu',
#  'boende',
#  'leo',
#  'pechenga',
#  'palabuhanratu',
#  'san policarpo',
#  'colac',
#  'zhezkazgan',
#  'sandwick',
#  'peplos',
#  'lompoc',
#  'mazara del vallo',
#  'taoudenni',
#  'kyra',
#  'bilma',
#  'dingle',
#  'xining',
#  'muravlenko',
#  'kormilovka',
#  'saint-pierre',
#  'veracruz',
#  'verkhnevilyuysk',
#  'sini',
#  'mayo',
#  'kemptville',
#  'along',
#  'emmett',
#  'los lunas',
#  'gao',
#  'ulladulla',
#  'domoni',
#  'ostrovnoy',
#  'mareeba',
#  'bay roberts',
#  'sadu',
#  'stege',
#  'sioux lookout',
#  'soure',
#  'sumbawanga',
#  'grindavik',
#  'san jose',
#  'bilibino',
#  'kimbe',
#  'lorengau',
#  'negombo',
#  'grand river south east',
#  'santa rosalia',
#  'alugan',
#  'lethem',
#  'inverness',
#  'ribeira grande',
#  'jardim',
#  'prince rupert',
#  'fort saint john',
#  'provost',
#  'paamiut',
#  'gamboula',
#  'akyab',
#  'iquitos',
#  'chumikan',
#  'carballo',
#  'kirakira',
#  'cap malheureux',
#  'pavlovo',
#  'kota kinabalu',
#  'vypolzovo',
#  'farafangana',
#  'krk',
#  'artyk',
#  'visby',
#  'north bend',
#  'uglovskoye',
#  'hirara',
#  'plettenberg bay',
#  'vrangel',
#  'yanam',
#  'sobolevo',
#  'sakaiminato',
#  'emba',
#  'emerald',
#  'labrea',
#  'metlika',
#  'abu samrah',
#  'namatanai',
#  'ribeira brava',
#  'martinsville',
#  'saint george',
#  'mazagao',
#  'malakal',
#  'dosso',
#  'brooks',
#  'zlatoustovsk',
#  'lingao',
#  'pangai',
#  'broadstairs',
#  'svetlaya',
#  'westport',
#  'mwinilunga',
#  'kabinda',
#  'addi ugri',
#  'rapid valley',
#  'marzuq',
#  'duyun',
#  'seminole',
#  'asayita',
#  'atasu',
#  'pacific grove',
#  'chifeng',
#  'dunedin',
#  'kidal',
#  'linjiang',
#  'volot',
#  'kysyl-syr',
#  'sumenep',
#  'piacabucu',
#  'peniche',
#  'caravelas',
#  'oksfjord',
#  'pemangkat',
#  'yichun',
#  'alotau',
#  'barcelos',
#  'jerez',
#  'almaty',
#  'huarmey',
#  'petatlan',
#  'miastko',
#  'aloleng',
#  'meyungs',
#  'eureka',
#  'karkaralinsk',
#  'lata',
#  'yelniki',
#  'port augusta',
#  'korla',
#  'ust-kamchatsk',
#  'clarence town',
#  'hamirpur',
#  'port-de-paix',
#  'nushki',
#  'takoradi',
#  'mubarakpur',
#  'rio brilhante',
#  'quatre cocos',
#  'zeya',
#  'novyy urengoy',
#  'champerico',
#  'yirol',
#  'tigil',
#  'papetoai',
#  'ust-shonosha',
#  'mitsamiouli',
#  'waingapu',
#  'maroantsetra',
#  'saint-joseph',
#  'baghdad',
#  'marawi',
#  'haukipudas',
#  'khunzakh',
#  'biltine',
#  'henties bay',
#  'gejiu',
#  'sao paulo de olivenca',
#  'buckeye',
#  'yoichi',
#  'banjar',
#  'portlethen',
#  'jiwani',
#  'toamasina',
#  'beni suef',
#  'sorland',
#  'samalaeulu',
#  'ranau',
#  'kailua',
#  'zyryanka',
#  'pemberton',
#  'srednekolymsk',
#  'talcahuano',
#  'bundaberg',
#  'winnemucca',
#  'taperoa',
#  'luau',
#  'port hardy',
#  'chicama',
#  'mountain home',
#  'taylorville',
#  'dibaya',
#  'umm durman',
#  'filingue',
#  'umm lajj',
#  'manta',
#  'balkanabat',
#  'meulaboh',
#  'ust-maya',
#  'hay river',
#  'arawa',
#  'wasilla',
#  'zhangjiakou',
#  'la ronge',
#  'morehead',
#  'karratha',
#  'stoyba',
#  'gornozavodsk',
#  'gezing',
#  'guarda',
#  'porto novo',
#  'selma',
#  'chapais',
#  'hokitika',
#  'omaruru',
#  'kingaroy',
#  'rusetu',
#  'cururupu',
#  'pangnirtung',
#  'dao',
#  'san isidro',
#  'lesnoy',
#  'valparaiso',
#  'saquarema',
#  'tongzi',
#  'antsohihy',
#  'bom sucesso',
#  'taltal',
#  'jumla',
#  'half moon bay',
#  'nanyamba',
#  'black river',
#  'terrace',
#  'praia da vitoria',
#  'san ignacio',
#  'rio grande',
#  'kwekwe',
#  'acari',
#  'te anau',
#  'ixtapa',
#  'khonuu',
#  'matara',
#  'gat',
#  'awjilah',
#  'asfi',
#  'boca do acre',
#  'bargal',
#  'teya',
#  'conde',
#  'tamna',
#  'aklavik',
#  'la asuncion',
#  'doctor pedro p. pena',
#  'puerto escondido',
#  'suntar',
#  'robertsport',
#  'bestobe',
#  'daxian',
#  'severo-kurilsk',
#  'akdepe',
#  'aleysk',
#  'pimentel',
#  'luanda',
#  'atlantic city',
#  'maracacume',
#  'george town',
#  'pauini',
#  'belfast',
#  'goderich',
#  'dinar',
#  'fairbanks',
#  'kieta',
#  'temir',
#  'dicabisagan',
#  'pangody',
#  'tibati',
#  'aromashevo',
#  'salgueiro',
#  'warri',
#  'methoni',
#  'lodja',
#  'bubaque',
#  'dolbeau',
#  'hervey bay',
#  'razole',
#  'bassila',
#  'brora',
#  'manaira',
#  'labutta',
#  'cam pha',
#  'troitsko-pechorsk',
#  'ondorhaan',
#  'bom jardim',
#  'ambovombe',
#  'hanzhong',
#  'mayna',
#  'abu dhabi',
#  'kerema',
#  'otradnoye',
#  'bom jesus',
#  'baykit',
#  'oranjemund',
#  'dhidhdhoo',
#  'auray',
#  'ossipee',
#  'wau',
#  'sentyabrskiy',
#  'rajpipla',
#  'samusu',
#  'khorixas',
#  'bage',
#  'the pas',
#  'jalu',
#  'kajaani',
#  'harsin',
#  'belle fourche',
#  'muroto',
#  'tautira',
#  'kavaratti',
#  'cordoba',
#  'zuwarah',
#  'gardan diwal',
#  'samana',
#  'cabedelo',
#  'khovu-aksy',
#  'aflu',
#  'kolvereid',
#  'ormond beach',
#  'turochak',
#  'bakchar',
#  'acapulco',
#  'sambava',
#  'pitimbu',
#  'palmer',
#  'mandalgovi',
#  'inirida',
#  'camacha',
#  'svetlyy',
#  'lakes entrance',
#  'guajara-mirim',
#  'saint simons',
#  'alice springs',
#  'biograd na moru',
#  'haapiti',
#  'pedra branca',
#  'airai',
#  'lerum',
#  'boa vista',
#  'evensk',
#  'hwange',
#  'huanren',
#  'port blair',
#  'timra',
#  'bayan',
#  'qaqortoq',
#  'okhotsk',
#  'liberty',
#  'santa cruz',
#  'humaita']

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests as req
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #retrieve city data
    # Run an API request for each of the cities.
    try:
            # Parse the JSON and retrieve data.
            print("trying connect")
            print(city_url)
            city_weather = req.get(city_url).json()
            print("connected")
            #Parse out the needed data.
            print("trying lat")
            city_lat = city_weather["coord"]["lat"]
            print("trying lon")
            city_lng = city_weather["coord"]["lon"]
            print("trying max")            
            city_max_temp = city_weather["main"]["temp_max"]
            print("trying humidity")
            city_humidity = city_weather["main"]["humidity"]
            print("trying clouds")
            city_clouds = city_weather["clouds"]["all"]
            print("trying speed")
            city_wind = city_weather["wind"]["speed"]
            print("trying country")
            city_country = city_weather["sys"]["country"]
            print("trying description")
            city_description = city_weather["weather"][0]["description"]
            # Append the city information into city_data list.
            print({"City": city,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Description" : city_description})
            city_data.append({"City": city,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Current Description" : city_description})
    # If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
            pass
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=albany
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'albany', 'Lat': 42.6, 'Lng': -73.97, 'Max Temp': 48.99, 'Humidity': 42, 'Cloudiness': 0, 'Wind Speed': 5.39, 'Country': 'US', 'Description': 'clear sky'}
# Processing Record 1 of Set 1 | albany
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=ushuaia
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'ushuaia', 'Lat': -54.8, 'Lng': -68.3, 'Max Temp': 51.8, 'Humidity': 50, 'Cloudiness': 40, 'Wind Speed': 3.36, 'Country': 'AR', 'Description': 'scattered clouds'}
# Processing Record 2 of Set 1 | ushuaia
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=college
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'college', 'Lat': 64.86, 'Lng': -147.8, 'Max Temp': 30, 'Humidity': 85, 'Cloudiness': 75, 'Wind Speed': 3.42, 'Country': 'US', 'Description': 'broken clouds'}
# Processing Record 3 of Set 1 | college
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=hobart
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'hobart', 'Lat': -42.88, 'Lng': 147.33, 'Max Temp': 44.6, 'Humidity': 81, 'Cloudiness': 75, 'Wind Speed': 6.93, 'Country': 'AU', 'Description': 'broken clouds'}
# Processing Record 4 of Set 1 | hobart
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=klyuchi
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'klyuchi', 'Lat': 52.27, 'Lng': 79.17, 'Max Temp': 38.71, 'Humidity': 82, 'Cloudiness': 100, 'Wind Speed': 15.19, 'Country': 'RU', 'Description': 'light rain'}
# Processing Record 5 of Set 1 | klyuchi
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=katra
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'katra', 'Lat': 32.98, 'Lng': 74.95, 'Max Temp': 59.59, 'Humidity': 33, 'Cloudiness': 0, 'Wind Speed': 10.94, 'Country': 'IN', 'Description': 'clear sky'}
# Processing Record 6 of Set 1 | katra
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=hermanus
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'hermanus', 'Lat': -34.42, 'Lng': 19.23, 'Max Temp': 61, 'Humidity': 79, 'Cloudiness': 98, 'Wind Speed': 13.62, 'Country': 'ZA', 'Description': 'overcast clouds'}
# Processing Record 7 of Set 1 | hermanus
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=shimoda
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'shimoda', 'Lat': 34.67, 'Lng': 138.95, 'Max Temp': 60.96, 'Humidity': 61, 'Cloudiness': 100, 'Wind Speed': 6.93, 'Country': 'JP', 'Description': 'overcast clouds'}
# Processing Record 8 of Set 1 | shimoda
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=vaitupu
# connected
# trying lat
# City not found. Skipping...
# Processing Record 9 of Set 1 | vaitupu
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=yugorsk
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'yugorsk', 'Lat': 61.31, 'Lng': 63.33, 'Max Temp': 24.91, 'Humidity': 99, 'Cloudiness': 94, 'Wind Speed': 2.33, 'Country': 'RU', 'Description': 'overcast clouds'}
# Processing Record 10 of Set 1 | yugorsk
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=nizhneyansk
# connected
# trying lat
# City not found. Skipping...
# Processing Record 11 of Set 1 | nizhneyansk
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=bengkulu
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'bengkulu', 'Lat': -3.8, 'Lng': 102.27, 'Max Temp': 74.93, 'Humidity': 89, 'Cloudiness': 100, 'Wind Speed': 4.18, 'Country': 'ID', 'Description': 'overcast clouds'}
# Processing Record 12 of Set 1 | bengkulu
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=hilo
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'hilo', 'Lat': 19.73, 'Lng': -155.09, 'Max Temp': 82.4, 'Humidity': 74, 'Cloudiness': 40, 'Wind Speed': 5.82, 'Country': 'US', 'Description': 'scattered clouds'}
# Processing Record 13 of Set 1 | hilo
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=boyolangu
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'boyolangu', 'Lat': -8.12, 'Lng': 111.89, 'Max Temp': 75.7, 'Humidity': 90, 'Cloudiness': 100, 'Wind Speed': 2.39, 'Country': 'ID', 'Description': 'overcast clouds'}
# Processing Record 14 of Set 1 | boyolangu
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=vila
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'vila', 'Lat': 42.03, 'Lng': -8.16, 'Max Temp': 45, 'Humidity': 94, 'Cloudiness': 100, 'Wind Speed': 3, 'Country': 'PT', 'Description': 'light rain'}
# Processing Record 15 of Set 1 | vila
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=puerto+ayora
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'puerto ayora', 'Lat': -0.74, 'Lng': -90.35, 'Max Temp': 78.8, 'Humidity': 69, 'Cloudiness': 40, 'Wind Speed': 20.8, 'Country': 'EC', 'Description': 'scattered clouds'}
# Processing Record 16 of Set 1 | puerto ayora
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=rikitea
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'rikitea', 'Lat': -23.12, 'Lng': -134.97, 'Max Temp': 73.81, 'Humidity': 80, 'Cloudiness': 100, 'Wind Speed': 19.08, 'Country': 'PF', 'Description': 'overcast clouds'}
# Processing Record 17 of Set 1 | rikitea
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=le+port
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'le port', 'Lat': -20.94, 'Lng': 55.29, 'Max Temp': 73.4, 'Humidity': 69, 'Cloudiness': 40, 'Wind Speed': 18.34, 'Country': 'RE', 'Description': 'scattered clouds'}
# Processing Record 18 of Set 1 | le port
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=hualmay
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'hualmay', 'Lat': -11.1, 'Lng': -77.61, 'Max Temp': 68.94, 'Humidity': 68, 'Cloudiness': 25, 'Wind Speed': 10.63, 'Country': 'PE', 'Description': 'scattered clouds'}
# Processing Record 19 of Set 1 | hualmay
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=ponta+do+sol
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'ponta do sol', 'Lat': 32.67, 'Lng': -17.1, 'Max Temp': 66.2, 'Humidity': 72, 'Cloudiness': 20, 'Wind Speed': 3.36, 'Country': 'PT', 'Description': 'few clouds'}
# Processing Record 20 of Set 1 | ponta do sol
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=saleaula
# connected
# trying lat
# City not found. Skipping...
# Processing Record 21 of Set 1 | saleaula
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=lolua
# connected
# trying lat
# City not found. Skipping...
# Processing Record 22 of Set 1 | lolua
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=nanortalik
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'nanortalik', 'Lat': 60.14, 'Lng': -45.24, 'Max Temp': 35.49, 'Humidity': 84, 'Cloudiness': 100, 'Wind Speed': 16.49, 'Country': 'GL', 'Description': 'overcast clouds'}
# Processing Record 23 of Set 1 | nanortalik
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=georgetown
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'georgetown', 'Lat': 5.41, 'Lng': 100.34, 'Max Temp': 77, 'Humidity': 94, 'Cloudiness': 40, 'Wind Speed': 2.24, 'Country': 'MY', 'Description': 'scattered clouds'}
# Processing Record 24 of Set 1 | georgetown
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=ukiah
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'ukiah', 'Lat': 39.15, 'Lng': -123.21, 'Max Temp': 57, 'Humidity': 71, 'Cloudiness': 40, 'Wind Speed': 4, 'Country': 'US', 'Description': 'scattered clouds'}
# Processing Record 25 of Set 1 | ukiah
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=busselton
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'busselton', 'Lat': -33.65, 'Lng': 115.33, 'Max Temp': 55, 'Humidity': 65, 'Cloudiness': 0, 'Wind Speed': 0.43, 'Country': 'AU', 'Description': 'clear sky'}
# Processing Record 26 of Set 1 | busselton
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=mataura
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'mataura', 'Lat': -46.19, 'Lng': 168.86, 'Max Temp': 46.99, 'Humidity': 97, 'Cloudiness': 99, 'Wind Speed': 2.15, 'Country': 'NZ', 'Description': 'overcast clouds'}
# Processing Record 27 of Set 1 | mataura
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=miri
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'miri', 'Lat': 4.41, 'Lng': 114.01, 'Max Temp': 77, 'Humidity': 94, 'Cloudiness': 40, 'Wind Speed': 4.7, 'Country': 'MY', 'Description': 'scattered clouds'}
# Processing Record 28 of Set 1 | miri
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=vaini
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'vaini', 'Lat': -21.2, 'Lng': -175.2, 'Max Temp': 71.6, 'Humidity': 94, 'Cloudiness': 90, 'Wind Speed': 10.29, 'Country': 'TO', 'Description': 'light intensity shower rain'}
# Processing Record 29 of Set 1 | vaini
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=puerto+del+rosario
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'puerto del rosario', 'Lat': 28.5, 'Lng': -13.86, 'Max Temp': 69.8, 'Humidity': 73, 'Cloudiness': 20, 'Wind Speed': 19.46, 'Country': 'ES', 'Description': 'few clouds'}
# Processing Record 30 of Set 1 | puerto del rosario
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=nemuro
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'nemuro', 'Lat': 43.32, 'Lng': 145.57, 'Max Temp': 48.78, 'Humidity': 72, 'Cloudiness': 0, 'Wind Speed': 17.96, 'Country': 'JP', 'Description': 'clear sky'}
# Processing Record 31 of Set 1 | nemuro
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=faanui
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'faanui', 'Lat': -16.48, 'Lng': -151.75, 'Max Temp': 80.02, 'Humidity': 69, 'Cloudiness': 0, 'Wind Speed': 4.61, 'Country': 'PF', 'Description': 'clear sky'}
# Processing Record 32 of Set 1 | faanui
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=we
# connected
# trying lat
# City not found. Skipping...
# Processing Record 33 of Set 1 | we
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=fuxin
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'fuxin', 'Lat': 42.02, 'Lng': 121.66, 'Max Temp': 46.47, 'Humidity': 54, 'Cloudiness': 0, 'Wind Speed': 2.08, 'Country': 'CN', 'Description': 'clear sky'}
# Processing Record 34 of Set 1 | fuxin
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=butaritari
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'butaritari', 'Lat': 3.07, 'Lng': 172.79, 'Max Temp': 81.09, 'Humidity': 70, 'Cloudiness': 62, 'Wind Speed': 9.17, 'Country': 'KI', 'Description': 'broken clouds'}
# Processing Record 35 of Set 1 | butaritari
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=danjiangkou
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'danjiangkou', 'Lat': 32.54, 'Lng': 111.51, 'Max Temp': 63.72, 'Humidity': 54, 'Cloudiness': 99, 'Wind Speed': 2.04, 'Country': 'CN', 'Description': 'light rain'}
# Processing Record 36 of Set 1 | danjiangkou
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=belushya+guba
# connected
# trying lat
# City not found. Skipping...
# Processing Record 37 of Set 1 | belushya guba
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=mar+del+plata
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'mar del plata', 'Lat': -38, 'Lng': -57.56, 'Max Temp': 62.6, 'Humidity': 100, 'Cloudiness': 90, 'Wind Speed': 3.36, 'Country': 'AR', 'Description': 'moderate rain'}
# Processing Record 38 of Set 1 | mar del plata
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=kruisfontein
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'kruisfontein', 'Lat': -34, 'Lng': 24.73, 'Max Temp': 62.01, 'Humidity': 90, 'Cloudiness': 100, 'Wind Speed': 10.67, 'Country': 'ZA', 'Description': 'light rain'}
# Processing Record 39 of Set 1 | kruisfontein
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=dongsheng
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'dongsheng', 'Lat': 39.82, 'Lng': 109.98, 'Max Temp': 43.95, 'Humidity': 56, 'Cloudiness': 0, 'Wind Speed': 13.29, 'Country': 'CN', 'Description': 'clear sky'}
# Processing Record 40 of Set 1 | dongsheng
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=punta+arenas
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'punta arenas', 'Lat': -53.15, 'Lng': -70.92, 'Max Temp': 44.6, 'Humidity': 81, 'Cloudiness': 40, 'Wind Speed': 8.05, 'Country': 'CL', 'Description': 'scattered clouds'}
# Processing Record 41 of Set 1 | punta arenas
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=sabang
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'sabang', 'Lat': 5.89, 'Lng': 95.32, 'Max Temp': 81.75, 'Humidity': 75, 'Cloudiness': 100, 'Wind Speed': 15.77, 'Country': 'ID', 'Description': 'overcast clouds'}
# Processing Record 42 of Set 1 | sabang
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=kamenka
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'kamenka', 'Lat': 51.32, 'Lng': 42.77, 'Max Temp': 44.01, 'Humidity': 91, 'Cloudiness': 0, 'Wind Speed': 7.16, 'Country': 'RU', 'Description': 'clear sky'}
# Processing Record 43 of Set 1 | kamenka
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=fortuna
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'fortuna', 'Lat': 40.6, 'Lng': -124.16, 'Max Temp': 57.99, 'Humidity': 76, 'Cloudiness': 75, 'Wind Speed': 5.82, 'Country': 'US', 'Description': 'broken clouds'}
# Processing Record 44 of Set 1 | fortuna
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=awbari
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'awbari', 'Lat': 26.59, 'Lng': 12.78, 'Max Temp': 70.05, 'Humidity': 30, 'Cloudiness': 0, 'Wind Speed': 6.76, 'Country': 'LY', 'Description': 'clear sky'}
# Processing Record 45 of Set 1 | awbari
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=xichang
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'xichang', 'Lat': 27.9, 'Lng': 102.26, 'Max Temp': 62.13, 'Humidity': 78, 'Cloudiness': 99, 'Wind Speed': 0.47, 'Country': 'CN', 'Description': 'overcast clouds'}
# Processing Record 46 of Set 1 | xichang
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=raton
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'raton', 'Lat': 36.9, 'Lng': -104.44, 'Max Temp': 48.99, 'Humidity': 42, 'Cloudiness': 1, 'Wind Speed': 13.87, 'Country': 'US', 'Description': 'clear sky'}
# Processing Record 47 of Set 1 | raton
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=longyearbyen
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'longyearbyen', 'Lat': 78.22, 'Lng': 15.64, 'Max Temp': 30.2, 'Humidity': 74, 'Cloudiness': 75, 'Wind Speed': 9.17, 'Country': 'SJ', 'Description': 'broken clouds'}
# Processing Record 48 of Set 1 | longyearbyen
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=tiksi
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'tiksi', 'Lat': 71.69, 'Lng': 128.87, 'Max Temp': 4.69, 'Humidity': 90, 'Cloudiness': 100, 'Wind Speed': 30.51, 'Country': 'RU', 'Description': 'overcast clouds'}
# Processing Record 49 of Set 1 | tiksi
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=quang+ngai
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'quang ngai', 'Lat': 15.12, 'Lng': 108.8, 'Max Temp': 75.63, 'Humidity': 92, 'Cloudiness': 98, 'Wind Speed': 1.77, 'Country': 'VN', 'Description': 'overcast clouds'}
# Processing Record 50 of Set 1 | quang ngai
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=marcona
# connected
# trying lat
# City not found. Skipping...
# Processing Record 1 of Set 2 | marcona
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=geraldton
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'geraldton', 'Lat': -28.77, 'Lng': 114.6, 'Max Temp': 62.6, 'Humidity': 88, 'Cloudiness': 0, 'Wind Speed': 6.93, 'Country': 'AU', 'Description': 'clear sky'}
# Processing Record 2 of Set 2 | geraldton
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=nikolskoye
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'nikolskoye', 'Lat': 59.7, 'Lng': 30.79, 'Max Temp': 42.8, 'Humidity': 93, 'Cloudiness': 90, 'Wind Speed': 4.47, 'Country': 'RU', 'Description': 'overcast clouds'}
# Processing Record 3 of Set 2 | nikolskoye
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=san+quintin
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'san quintin', 'Lat': 30.48, 'Lng': -115.95, 'Max Temp': 70.07, 'Humidity': 60, 'Cloudiness': 63, 'Wind Speed': 12.06, 'Country': 'MX', 'Description': 'broken clouds'}
# Processing Record 4 of Set 2 | san quintin
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=havre-saint-pierre
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'havre-saint-pierre', 'Lat': 50.23, 'Lng': -63.6, 'Max Temp': 39.2, 'Humidity': 44, 'Cloudiness': 20, 'Wind Speed': 14.99, 'Country': 'CA', 'Description': 'few clouds'}
# Processing Record 5 of Set 2 | havre-saint-pierre
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=bethel
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'bethel', 'Lat': 41.37, 'Lng': -73.41, 'Max Temp': 52, 'Humidity': 48, 'Cloudiness': 40, 'Wind Speed': 5.82, 'Country': 'US', 'Description': 'scattered clouds'}
# Processing Record 6 of Set 2 | bethel
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=kahului
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'kahului', 'Lat': 20.89, 'Lng': -156.47, 'Max Temp': 87.8, 'Humidity': 52, 'Cloudiness': 20, 'Wind Speed': 4.7, 'Country': 'US', 'Description': 'few clouds'}
# Processing Record 7 of Set 2 | kahului
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=mys+shmidta
# connected
# trying lat
# City not found. Skipping...
# Processing Record 8 of Set 2 | mys shmidta
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=cape+town
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'cape town', 'Lat': -33.93, 'Lng': 18.42, 'Max Temp': 63, 'Humidity': 82, 'Cloudiness': 20, 'Wind Speed': 16.11, 'Country': 'ZA', 'Description': 'few clouds'}
# Processing Record 9 of Set 2 | cape town
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=beroroha
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'beroroha', 'Lat': -21.67, 'Lng': 45.17, 'Max Temp': 74.95, 'Humidity': 56, 'Cloudiness': 98, 'Wind Speed': 11.23, 'Country': 'MG', 'Description': 'overcast clouds'}
# Processing Record 10 of Set 2 | beroroha
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=mahebourg
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'mahebourg', 'Lat': -20.41, 'Lng': 57.7, 'Max Temp': 75.2, 'Humidity': 73, 'Cloudiness': 75, 'Wind Speed': 14.99, 'Country': 'MU', 'Description': 'shower rain'}
# Processing Record 11 of Set 2 | mahebourg
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=chokurdakh
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'chokurdakh', 'Lat': 70.63, 'Lng': 147.92, 'Max Temp': 6.03, 'Humidity': 93, 'Cloudiness': 0, 'Wind Speed': 9.89, 'Country': 'RU', 'Description': 'clear sky'}
# Processing Record 12 of Set 2 | chokurdakh
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=souillac
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'souillac', 'Lat': -20.52, 'Lng': 57.52, 'Max Temp': 75.2, 'Humidity': 73, 'Cloudiness': 75, 'Wind Speed': 14.99, 'Country': 'MU', 'Description': 'shower rain'}
# Processing Record 13 of Set 2 | souillac
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=iqaluit
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'iqaluit', 'Lat': 63.75, 'Lng': -68.51, 'Max Temp': 8.6, 'Humidity': 84, 'Cloudiness': 20, 'Wind Speed': 8.05, 'Country': 'CA', 'Description': 'few clouds'}
# Processing Record 14 of Set 2 | iqaluit
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=qasigiannguit
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'qasigiannguit', 'Lat': 68.82, 'Lng': -51.19, 'Max Temp': 15.8, 'Humidity': 52, 'Cloudiness': 54, 'Wind Speed': 6.93, 'Country': 'GL', 'Description': 'broken clouds'}
# Processing Record 15 of Set 2 | qasigiannguit
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=bluff
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'bluff', 'Lat': -46.6, 'Lng': 168.33, 'Max Temp': 46.99, 'Humidity': 97, 'Cloudiness': 36, 'Wind Speed': 8.86, 'Country': 'NZ', 'Description': 'scattered clouds'}
# Processing Record 16 of Set 2 | bluff
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=sola
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'sola', 'Lat': -13.88, 'Lng': 167.55, 'Max Temp': 79.83, 'Humidity': 82, 'Cloudiness': 5, 'Wind Speed': 18.1, 'Country': 'VU', 'Description': 'light rain'}
# Processing Record 17 of Set 2 | sola
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=portland
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'portland', 'Lat': 45.52, 'Lng': -122.68, 'Max Temp': 46, 'Humidity': 28, 'Cloudiness': 20, 'Wind Speed': 17.22, 'Country': 'US', 'Description': 'few clouds'}
# Processing Record 18 of Set 2 | portland
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=saint-ambroise
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'saint-ambroise', 'Lat': 48.55, 'Lng': -71.33, 'Max Temp': 37.4, 'Humidity': 40, 'Cloudiness': 20, 'Wind Speed': 17.22, 'Country': 'CA', 'Description': 'few clouds'}
# Processing Record 19 of Set 2 | saint-ambroise
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=mount+gambier
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'mount gambier', 'Lat': -37.83, 'Lng': 140.77, 'Max Temp': 41, 'Humidity': 86, 'Cloudiness': 40, 'Wind Speed': 8.05, 'Country': 'AU', 'Description': 'scattered clouds'}
# Processing Record 20 of Set 2 | mount gambier
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=tunduru
# connected
# trying lat
# City not found. Skipping...
# Processing Record 21 of Set 2 | tunduru
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=berlevag
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'berlevag', 'Lat': 70.86, 'Lng': 29.09, 'Max Temp': 33.8, 'Humidity': 86, 'Cloudiness': 75, 'Wind Speed': 13.87, 'Country': 'NO', 'Description': 'broken clouds'}
# Processing Record 22 of Set 2 | berlevag
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=jamestown
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'jamestown', 'Lat': 42.1, 'Lng': -79.24, 'Max Temp': 46, 'Humidity': 63, 'Cloudiness': 90, 'Wind Speed': 10.29, 'Country': 'US', 'Description': 'overcast clouds'}
# Processing Record 23 of Set 2 | jamestown
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=leningradskiy
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'leningradskiy', 'Lat': 69.38, 'Lng': 178.42, 'Max Temp': 23.5, 'Humidity': 89, 'Cloudiness': 49, 'Wind Speed': 6.11, 'Country': 'RU', 'Description': 'scattered clouds'}
# Processing Record 24 of Set 2 | leningradskiy
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=marsa+matruh
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'marsa matruh', 'Lat': 31.35, 'Lng': 27.25, 'Max Temp': 73.4, 'Humidity': 69, 'Cloudiness': 40, 'Wind Speed': 10.29, 'Country': 'EG', 'Description': 'scattered clouds'}
# Processing Record 25 of Set 2 | marsa matruh
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=halifax
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'halifax', 'Lat': 44.65, 'Lng': -63.57, 'Max Temp': 46.99, 'Humidity': 61, 'Cloudiness': 0, 'Wind Speed': 5.01, 'Country': 'CA', 'Description': 'clear sky'}
# Processing Record 26 of Set 2 | halifax
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=saint-philippe
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'saint-philippe', 'Lat': -21.36, 'Lng': 55.77, 'Max Temp': 69.8, 'Humidity': 73, 'Cloudiness': 0, 'Wind Speed': 5.82, 'Country': 'RE', 'Description': 'clear sky'}
# Processing Record 27 of Set 2 | saint-philippe
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=hithadhoo
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'hithadhoo', 'Lat': -0.6, 'Lng': 73.08, 'Max Temp': 82.98, 'Humidity': 71, 'Cloudiness': 27, 'Wind Speed': 5.39, 'Country': 'MV', 'Description': 'scattered clouds'}
# Processing Record 28 of Set 2 | hithadhoo
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=olafsvik
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'olafsvik', 'Lat': 64.89, 'Lng': -23.71, 'Max Temp': 42.75, 'Humidity': 82, 'Cloudiness': 100, 'Wind Speed': 27.51, 'Country': 'IS', 'Description': 'overcast clouds'}
# Processing Record 29 of Set 2 | olafsvik
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=hamilton
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'hamilton', 'Lat': 39.18, 'Lng': -84.53, 'Max Temp': 54, 'Humidity': 66, 'Cloudiness': 90, 'Wind Speed': 10.29, 'Country': 'US', 'Description': 'overcast clouds'}
# Processing Record 30 of Set 2 | hamilton
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=eldorado
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'eldorado', 'Lat': -23.79, 'Lng': -54.28, 'Max Temp': 88.41, 'Humidity': 49, 'Cloudiness': 86, 'Wind Speed': 1.95, 'Country': 'BR', 'Description': 'overcast clouds'}
# Processing Record 31 of Set 2 | eldorado
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=avarua
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'avarua', 'Lat': -21.21, 'Lng': -159.78, 'Max Temp': 75.2, 'Humidity': 73, 'Cloudiness': 49, 'Wind Speed': 11.41, 'Country': 'CK', 'Description': 'light rain'}
# Processing Record 32 of Set 2 | avarua
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=kodiak
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'kodiak', 'Lat': 57.79, 'Lng': -152.41, 'Max Temp': 48.2, 'Humidity': 87, 'Cloudiness': 90, 'Wind Speed': 17.22, 'Country': 'US', 'Description': 'mist'}
# Processing Record 33 of Set 2 | kodiak
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=vestmannaeyjar
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'vestmannaeyjar', 'Lat': 63.44, 'Lng': -20.27, 'Max Temp': 42.8, 'Humidity': 81, 'Cloudiness': 75, 'Wind Speed': 2.24, 'Country': 'IS', 'Description': 'broken clouds'}
# Processing Record 34 of Set 2 | vestmannaeyjar
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=kandrian
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'kandrian', 'Lat': -6.22, 'Lng': 149.55, 'Max Temp': 77.5, 'Humidity': 82, 'Cloudiness': 85, 'Wind Speed': 4.43, 'Country': 'PG', 'Description': 'light rain'}
# Processing Record 35 of Set 2 | kandrian
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=yanan
# connected
# trying lat
# City not found. Skipping...
# Processing Record 36 of Set 2 | yanan
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=nuuk
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'nuuk', 'Lat': 64.18, 'Lng': -51.72, 'Max Temp': 26.6, 'Humidity': 79, 'Cloudiness': 100, 'Wind Speed': 12.75, 'Country': 'GL', 'Description': 'overcast clouds'}
# Processing Record 37 of Set 2 | nuuk
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=sitka
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'sitka', 'Lat': 57.05, 'Lng': -135.33, 'Max Temp': 42.8, 'Humidity': 75, 'Cloudiness': 90, 'Wind Speed': 12.75, 'Country': 'US', 'Description': 'light rain'}
# Processing Record 38 of Set 2 | sitka
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=plattsburgh
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'plattsburgh', 'Lat': 44.7, 'Lng': -73.45, 'Max Temp': 42.8, 'Humidity': 48, 'Cloudiness': 1, 'Wind Speed': 10.29, 'Country': 'US', 'Description': 'clear sky'}
# Processing Record 39 of Set 2 | plattsburgh
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=presidencia+roque+saenz+pena
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'presidencia roque saenz pena', 'Lat': -26.79, 'Lng': -60.44, 'Max Temp': 95.36, 'Humidity': 36, 'Cloudiness': 88, 'Wind Speed': 6.58, 'Country': 'AR', 'Description': 'overcast clouds'}
# Processing Record 40 of Set 2 | presidencia roque saenz pena
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=lyubim
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'lyubim', 'Lat': 58.36, 'Lng': 40.68, 'Max Temp': 35.96, 'Humidity': 90, 'Cloudiness': 77, 'Wind Speed': 4.45, 'Country': 'RU', 'Description': 'broken clouds'}
# Processing Record 41 of Set 2 | lyubim
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=uthal
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'uthal', 'Lat': 25.81, 'Lng': 66.62, 'Max Temp': 72.48, 'Humidity': 47, 'Cloudiness': 0, 'Wind Speed': 0.56, 'Country': 'PK', 'Description': 'clear sky'}
# Processing Record 42 of Set 2 | uthal
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=nouadhibou
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'nouadhibou', 'Lat': 20.93, 'Lng': -17.03, 'Max Temp': 75.2, 'Humidity': 64, 'Cloudiness': 100, 'Wind Speed': 12.75, 'Country': 'MR', 'Description': 'overcast clouds'}
# Processing Record 43 of Set 2 | nouadhibou
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=shenjiamen
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'shenjiamen', 'Lat': 29.96, 'Lng': 122.3, 'Max Temp': 63.79, 'Humidity': 67, 'Cloudiness': 1, 'Wind Speed': 5.21, 'Country': 'CN', 'Description': 'clear sky'}
# Processing Record 44 of Set 2 | shenjiamen
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=bulungu
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'bulungu', 'Lat': -4.55, 'Lng': 18.6, 'Max Temp': 73.74, 'Humidity': 92, 'Cloudiness': 100, 'Wind Speed': 2.35, 'Country': 'CD', 'Description': 'overcast clouds'}
# Processing Record 45 of Set 2 | bulungu
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=narsaq
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'narsaq', 'Lat': 60.92, 'Lng': -46.05, 'Max Temp': 39.2, 'Humidity': 60, 'Cloudiness': 100, 'Wind Speed': 18.34, 'Country': 'GL', 'Description': 'overcast clouds'}
# Processing Record 46 of Set 2 | narsaq
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=khatanga
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'khatanga', 'Lat': 71.97, 'Lng': 102.5, 'Max Temp': 6.35, 'Humidity': 95, 'Cloudiness': 90, 'Wind Speed': 9.93, 'Country': 'RU', 'Description': 'overcast clouds'}
# Processing Record 47 of Set 2 | khatanga
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=port+lincoln
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'port lincoln', 'Lat': -34.73, 'Lng': 135.87, 'Max Temp': 51.84, 'Humidity': 63, 'Cloudiness': 60, 'Wind Speed': 15.88, 'Country': 'AU', 'Description': 'broken clouds'}
# Processing Record 48 of Set 2 | port lincoln
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=kanniyakumari
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'kanniyakumari', 'Lat': 8.08, 'Lng': 77.57, 'Max Temp': 79.38, 'Humidity': 80, 'Cloudiness': 85, 'Wind Speed': 14.54, 'Country': 'IN', 'Description': 'light rain'}
# Processing Record 49 of Set 2 | kanniyakumari
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=nova+russas
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'nova russas', 'Lat': -4.71, 'Lng': -40.56, 'Max Temp': 95.76, 'Humidity': 25, 'Cloudiness': 66, 'Wind Speed': 6.35, 'Country': 'BR', 'Description': 'broken clouds'}
# Processing Record 50 of Set 2 | nova russas
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=potiskum
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'potiskum', 'Lat': 11.71, 'Lng': 11.07, 'Max Temp': 85.44, 'Humidity': 20, 'Cloudiness': 90, 'Wind Speed': 11.05, 'Country': 'NG', 'Description': 'overcast clouds'}
# Processing Record 1 of Set 3 | potiskum
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=guerrero+negro
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'guerrero negro', 'Lat': 27.98, 'Lng': -114.06, 'Max Temp': 72.75, 'Humidity': 59, 'Cloudiness': 50, 'Wind Speed': 16.89, 'Country': 'MX', 'Description': 'scattered clouds'}
# Processing Record 2 of Set 3 | guerrero negro
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=zychlin
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'zychlin', 'Lat': 52.24, 'Lng': 19.63, 'Max Temp': 52, 'Humidity': 91, 'Cloudiness': 0, 'Wind Speed': 5.99, 'Country': 'PL', 'Description': 'clear sky'}
# Processing Record 3 of Set 3 | zychlin
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=yellowknife
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'yellowknife', 'Lat': 62.46, 'Lng': -114.35, 'Max Temp': 30, 'Humidity': 74, 'Cloudiness': 75, 'Wind Speed': 8.05, 'Country': 'CA', 'Description': 'broken clouds'}
# Processing Record 4 of Set 3 | yellowknife
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=kawalu
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'kawalu', 'Lat': -7.38, 'Lng': 108.21, 'Max Temp': 72.73, 'Humidity': 93, 'Cloudiness': 100, 'Wind Speed': 2.04, 'Country': 'ID', 'Description': 'overcast clouds'}
# Processing Record 5 of Set 3 | kawalu
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=oceanside
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'oceanside', 'Lat': 33.2, 'Lng': -117.38, 'Max Temp': 69.01, 'Humidity': 82, 'Cloudiness': 90, 'Wind Speed': 11.41, 'Country': 'US', 'Description': 'overcast clouds'}
# Processing Record 6 of Set 3 | oceanside
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=spornoye
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'spornoye', 'Lat': 50.84, 'Lng': 37.29, 'Max Temp': 48.2, 'Humidity': 81, 'Cloudiness': 75, 'Wind Speed': 2.24, 'Country': 'RU', 'Description': 'broken clouds'}
# Processing Record 7 of Set 3 | spornoye
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=burnie
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'burnie', 'Lat': -41.07, 'Lng': 145.92, 'Max Temp': 41, 'Humidity': 70, 'Cloudiness': 0, 'Wind Speed': 8.99, 'Country': 'AU', 'Description': 'clear sky'}
# Processing Record 8 of Set 3 | burnie
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=carutapera
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'carutapera', 'Lat': -1.2, 'Lng': -46.02, 'Max Temp': 83.5, 'Humidity': 66, 'Cloudiness': 100, 'Wind Speed': 7.74, 'Country': 'BR', 'Description': 'moderate rain'}
# Processing Record 9 of Set 3 | carutapera
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=tynda
# connected
# trying lat
# trying lon
# ...
# trying speed
# trying country
# trying description
# {'City': 'cabedelo', 'Lat': -6.98, 'Lng': -34.83, 'Max Temp': 80.6, 'Humidity': 78, 'Cloudiness': 40, 'Wind Speed': 11.41, 'Country': 'BR', 'Description': 'scattered clouds'}
# Processing Record 15 of Set 15 | cabedelo
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=khovu-aksy
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'khovu-aksy', 'Lat': 51.13, 'Lng': 93.6, 'Max Temp': 20.05, 'Humidity': 78, 'Cloudiness': 100, 'Wind Speed': 3.87, 'Country': 'RU', 'Description': 'overcast clouds'}
# Processing Record 16 of Set 15 | khovu-aksy
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=aflu
# connected
# trying lat
# City not found. Skipping...
# Processing Record 17 of Set 15 | aflu
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=kolvereid
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'kolvereid', 'Lat': 64.87, 'Lng': 11.6, 'Max Temp': 46.4, 'Humidity': 93, 'Cloudiness': 75, 'Wind Speed': 10.29, 'Country': 'NO', 'Description': 'shower rain'}
# Processing Record 18 of Set 15 | kolvereid
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=ormond+beach
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'ormond beach', 'Lat': 29.29, 'Lng': -81.06, 'Max Temp': 82.4, 'Humidity': 74, 'Cloudiness': 20, 'Wind Speed': 11.41, 'Country': 'US', 'Description': 'few clouds'}
# Processing Record 19 of Set 15 | ormond beach
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=turochak
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'turochak', 'Lat': 52.26, 'Lng': 87.12, 'Max Temp': 32.18, 'Humidity': 85, 'Cloudiness': 100, 'Wind Speed': 2.24, 'Country': 'RU', 'Description': 'overcast clouds'}
# Processing Record 20 of Set 15 | turochak
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=bakchar
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'bakchar', 'Lat': 57.02, 'Lng': 82.07, 'Max Temp': 29.41, 'Humidity': 98, 'Cloudiness': 100, 'Wind Speed': 8.63, 'Country': 'RU', 'Description': 'overcast clouds'}
# Processing Record 21 of Set 15 | bakchar
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=acapulco
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'acapulco', 'Lat': 16.86, 'Lng': -99.89, 'Max Temp': 87.8, 'Humidity': 79, 'Cloudiness': 40, 'Wind Speed': 5.82, 'Country': 'MX', 'Description': 'scattered clouds'}
# Processing Record 22 of Set 15 | acapulco
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=sambava
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'sambava', 'Lat': -14.27, 'Lng': 50.17, 'Max Temp': 71.94, 'Humidity': 82, 'Cloudiness': 1, 'Wind Speed': 9.89, 'Country': 'MG', 'Description': 'clear sky'}
# Processing Record 23 of Set 15 | sambava
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=pitimbu
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'pitimbu', 'Lat': -7.47, 'Lng': -34.81, 'Max Temp': 80.6, 'Humidity': 78, 'Cloudiness': 40, 'Wind Speed': 11.41, 'Country': 'BR', 'Description': 'scattered clouds'}
# Processing Record 24 of Set 15 | pitimbu
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=palmer
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'palmer', 'Lat': 42.16, 'Lng': -72.33, 'Max Temp': 52, 'Humidity': 46, 'Cloudiness': 75, 'Wind Speed': 10.29, 'Country': 'US', 'Description': 'broken clouds'}
# Processing Record 25 of Set 15 | palmer
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=mandalgovi
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'mandalgovi', 'Lat': 45.76, 'Lng': 106.27, 'Max Temp': 25.65, 'Humidity': 80, 'Cloudiness': 0, 'Wind Speed': 25.9, 'Country': 'MN', 'Description': 'clear sky'}
# Processing Record 26 of Set 15 | mandalgovi
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=inirida
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'inirida', 'Lat': 3.87, 'Lng': -67.92, 'Max Temp': 88.25, 'Humidity': 60, 'Cloudiness': 25, 'Wind Speed': 2.13, 'Country': 'CO', 'Description': 'scattered clouds'}
# Processing Record 27 of Set 15 | inirida
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=camacha
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'camacha', 'Lat': 33.08, 'Lng': -16.33, 'Max Temp': 68, 'Humidity': 72, 'Cloudiness': 40, 'Wind Speed': 14.99, 'Country': 'PT', 'Description': 'scattered clouds'}
# Processing Record 28 of Set 15 | camacha
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=svetlyy
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'svetlyy', 'Lat': 54.67, 'Lng': 20.13, 'Max Temp': 51.8, 'Humidity': 87, 'Cloudiness': 0, 'Wind Speed': 8.95, 'Country': 'RU', 'Description': 'clear sky'}
# Processing Record 29 of Set 15 | svetlyy
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=lakes+entrance
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'lakes entrance', 'Lat': -37.88, 'Lng': 147.98, 'Max Temp': 52, 'Humidity': 95, 'Cloudiness': 90, 'Wind Speed': 11.59, 'Country': 'AU', 'Description': 'overcast clouds'}
# Processing Record 30 of Set 15 | lakes entrance
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=guajara-mirim
# connected
# trying lat
# City not found. Skipping...
# Processing Record 31 of Set 15 | guajara-mirim
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=saint+simons
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'saint simons', 'Lat': 31.14, 'Lng': -81.39, 'Max Temp': 80.6, 'Humidity': 78, 'Cloudiness': 1, 'Wind Speed': 9.17, 'Country': 'US', 'Description': 'clear sky'}
# Processing Record 32 of Set 15 | saint simons
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=alice+springs
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'alice springs', 'Lat': -23.7, 'Lng': 133.88, 'Max Temp': 59, 'Humidity': 38, 'Cloudiness': 0, 'Wind Speed': 11.41, 'Country': 'AU', 'Description': 'clear sky'}
# Processing Record 33 of Set 15 | alice springs
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=biograd+na+moru
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'biograd na moru', 'Lat': 43.94, 'Lng': 15.45, 'Max Temp': 57, 'Humidity': 100, 'Cloudiness': 0, 'Wind Speed': 3.36, 'Country': 'HR', 'Description': 'clear sky'}
# Processing Record 34 of Set 15 | biograd na moru
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=haapiti
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'haapiti', 'Lat': -17.57, 'Lng': -149.87, 'Max Temp': 82.4, 'Humidity': 69, 'Cloudiness': 75, 'Wind Speed': 8.05, 'Country': 'PF', 'Description': 'shower rain'}
# Processing Record 35 of Set 15 | haapiti
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=pedra+branca
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'pedra branca', 'Lat': -5.45, 'Lng': -39.72, 'Max Temp': 90.73, 'Humidity': 30, 'Cloudiness': 30, 'Wind Speed': 8.21, 'Country': 'BR', 'Description': 'scattered clouds'}
# Processing Record 36 of Set 15 | pedra branca
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=airai
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'airai', 'Lat': -8.93, 'Lng': 125.41, 'Max Temp': 61.59, 'Humidity': 100, 'Cloudiness': 97, 'Wind Speed': 1.34, 'Country': 'TL', 'Description': 'overcast clouds'}
# Processing Record 37 of Set 15 | airai
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=lerum
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'lerum', 'Lat': 57.77, 'Lng': 12.27, 'Max Temp': 52, 'Humidity': 93, 'Cloudiness': 90, 'Wind Speed': 12.75, 'Country': 'SE', 'Description': 'light rain'}
# Processing Record 38 of Set 15 | lerum
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=boa+vista
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'boa vista', 'Lat': 2.82, 'Lng': -60.67, 'Max Temp': 96.8, 'Humidity': 37, 'Cloudiness': 40, 'Wind Speed': 8.05, 'Country': 'BR', 'Description': 'scattered clouds'}
# Processing Record 39 of Set 15 | boa vista
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=evensk
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'evensk', 'Lat': 61.95, 'Lng': 159.23, 'Max Temp': 32.4, 'Humidity': 92, 'Cloudiness': 100, 'Wind Speed': 14.25, 'Country': 'RU', 'Description': 'overcast clouds'}
# Processing Record 40 of Set 15 | evensk
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=hwange
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'hwange', 'Lat': -18.37, 'Lng': 26.5, 'Max Temp': 75.31, 'Humidity': 32, 'Cloudiness': 0, 'Wind Speed': 2.17, 'Country': 'ZW', 'Description': 'clear sky'}
# Processing Record 41 of Set 15 | hwange
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=huanren
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'huanren', 'Lat': 41.26, 'Lng': 125.37, 'Max Temp': 39.18, 'Humidity': 80, 'Cloudiness': 0, 'Wind Speed': 1.07, 'Country': 'CN', 'Description': 'clear sky'}
# Processing Record 42 of Set 15 | huanren
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=port+blair
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'port blair', 'Lat': 11.67, 'Lng': 92.75, 'Max Temp': 79.2, 'Humidity': 82, 'Cloudiness': 48, 'Wind Speed': 2.35, 'Country': 'IN', 'Description': 'moderate rain'}
# Processing Record 43 of Set 15 | port blair
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=timra
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'timra', 'Lat': 62.49, 'Lng': 17.33, 'Max Temp': 48.2, 'Humidity': 100, 'Cloudiness': 100, 'Wind Speed': 11.41, 'Country': 'SE', 'Description': 'overcast clouds'}
# Processing Record 44 of Set 15 | timra
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=bayan
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'bayan', 'Lat': 46.08, 'Lng': 127.4, 'Max Temp': 35.98, 'Humidity': 83, 'Cloudiness': 0, 'Wind Speed': 1.81, 'Country': 'CN', 'Description': 'clear sky'}
# Processing Record 45 of Set 15 | bayan
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=qaqortoq
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'qaqortoq', 'Lat': 60.72, 'Lng': -46.03, 'Max Temp': 39.2, 'Humidity': 60, 'Cloudiness': 100, 'Wind Speed': 18.34, 'Country': 'GL', 'Description': 'overcast clouds'}
# Processing Record 46 of Set 15 | qaqortoq
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=okhotsk
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'okhotsk', 'Lat': 59.38, 'Lng': 143.3, 'Max Temp': 32.92, 'Humidity': 86, 'Cloudiness': 94, 'Wind Speed': 23.96, 'Country': 'RU', 'Description': 'overcast clouds'}
# Processing Record 47 of Set 15 | okhotsk
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=liberty
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'liberty', 'Lat': 31.83, 'Lng': -81.5, 'Max Temp': 84.99, 'Humidity': 58, 'Cloudiness': 40, 'Wind Speed': 4.7, 'Country': 'US', 'Description': 'scattered clouds'}
# Processing Record 48 of Set 15 | liberty
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=santa+cruz
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'santa cruz', 'Lat': -17.8, 'Lng': -63.17, 'Max Temp': 95, 'Humidity': 44, 'Cloudiness': 75, 'Wind Speed': 25.28, 'Country': 'BO', 'Description': 'broken clouds'}
# Processing Record 49 of Set 15 | santa cruz
# trying connect
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=28522c72b9d3fa51410979910db28b42&q=humaita
# connected
# trying lat
# trying lon
# trying max
# trying humidity
# trying clouds
# trying speed
# trying country
# trying description
# {'City': 'humaita', 'Lat': -7.51, 'Lng': -63.02, 'Max Temp': 91.02, 'Humidity': 50, 'Cloudiness': 99, 'Wind Speed': 3.94, 'Country': 'BR', 'Description': 'overcast clouds'}
# Processing Record 50 of Set 15 | humaita
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 48.99,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 5.39,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 51.8,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Country': 'AR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'college',
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': 30,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 3.42,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'klyuchi',
#   'Lat': 52.27,
#   'Lng': 79.17,
#   'Max Temp': 38.71,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 15.19,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'katra',
#   'Lat': 32.98,
#   'Lng': 74.95,
#   'Max Temp': 59.59,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 10.94,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 61,
#   'Humidity': 79,
#   'Cloudiness': 98,
#   'Wind Speed': 13.62,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'shimoda',
#   'Lat': 34.67,
#   'Lng': 138.95,
#   'Max Temp': 60.96,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 6.93,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds'},
#  {'City': 'yugorsk',
#   'Lat': 61.31,
#   'Lng': 63.33,
#   'Max Temp': 24.91,
#   'Humidity': 99,
#   'Cloudiness': 94,
#   'Wind Speed': 2.33,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'bengkulu',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Max Temp': 74.93,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.18,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'boyolangu',
#   'Lat': -8.12,
#   'Lng': 111.89,
#   'Max Temp': 75.7,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.39,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'vila',
#   'Lat': 42.03,
#   'Lng': -8.16,
#   'Max Temp': 45,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'PT',
#   'Current Description': 'light rain'},
#  {'City': 'puerto ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 20.8,
#   'Country': 'EC',
#   'Current Description': 'scattered clouds'},
#  {'City': 'rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 73.81,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 19.08,
#   'Country': 'PF',
#   'Current Description': 'overcast clouds'},
#  {'City': 'le port',
#   'Lat': -20.94,
#   'Lng': 55.29,
#   'Max Temp': 73.4,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 18.34,
#   'Country': 'RE',
#   'Current Description': 'scattered clouds'},
#  {'City': 'hualmay',
#   'Lat': -11.1,
#   'Lng': -77.61,
#   'Max Temp': 68.94,
#   'Humidity': 68,
#   'Cloudiness': 25,
#   'Wind Speed': 10.63,
#   'Country': 'PE',
#   'Current Description': 'scattered clouds'},
#  {'City': 'ponta do sol',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 66.2,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Country': 'PT',
#   'Current Description': 'few clouds'},
#  {'City': 'nanortalik',
#   'Lat': 60.14,
#   'Lng': -45.24,
#   'Max Temp': 35.49,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 16.49,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Country': 'MY',
#   'Current Description': 'scattered clouds'},
#  {'City': 'ukiah',
#   'Lat': 39.15,
#   'Lng': -123.21,
#   'Max Temp': 57,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 55,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 0.43,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 46.99,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 2.15,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'miri',
#   'Lat': 4.41,
#   'Lng': 114.01,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'MY',
#   'Current Description': 'scattered clouds'},
#  {'City': 'vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Country': 'TO',
#   'Current Description': 'light intensity shower rain'},
#  {'City': 'puerto del rosario',
#   'Lat': 28.5,
#   'Lng': -13.86,
#   'Max Temp': 69.8,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 19.46,
#   'Country': 'ES',
#   'Current Description': 'few clouds'},
#  {'City': 'nemuro',
#   'Lat': 43.32,
#   'Lng': 145.57,
#   'Max Temp': 48.78,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 17.96,
#   'Country': 'JP',
#   'Current Description': 'clear sky'},
#  {'City': 'faanui',
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 80.02,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'PF',
#   'Current Description': 'clear sky'},
#  {'City': 'fuxin',
#   'Lat': 42.02,
#   'Lng': 121.66,
#   'Max Temp': 46.47,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 2.08,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 81.09,
#   'Humidity': 70,
#   'Cloudiness': 62,
#   'Wind Speed': 9.17,
#   'Country': 'KI',
#   'Current Description': 'broken clouds'},
#  {'City': 'danjiangkou',
#   'Lat': 32.54,
#   'Lng': 111.51,
#   'Max Temp': 63.72,
#   'Humidity': 54,
#   'Cloudiness': 99,
#   'Wind Speed': 2.04,
#   'Country': 'CN',
#   'Current Description': 'light rain'},
#  {'City': 'mar del plata',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 62.6,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Country': 'AR',
#   'Current Description': 'moderate rain'},
#  {'City': 'kruisfontein',
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 62.01,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 10.67,
#   'Country': 'ZA',
#   'Current Description': 'light rain'},
#  {'City': 'dongsheng',
#   'Lat': 39.82,
#   'Lng': 109.98,
#   'Max Temp': 43.95,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 13.29,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'punta arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CL',
#   'Current Description': 'scattered clouds'},
#  {'City': 'sabang',
#   'Lat': 5.89,
#   'Lng': 95.32,
#   'Max Temp': 81.75,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 15.77,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'kamenka',
#   'Lat': 51.32,
#   'Lng': 42.77,
#   'Max Temp': 44.01,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 7.16,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'fortuna',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 57.99,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'awbari',
#   'Lat': 26.59,
#   'Lng': 12.78,
#   'Max Temp': 70.05,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 6.76,
#   'Country': 'LY',
#   'Current Description': 'clear sky'},
#  {'City': 'xichang',
#   'Lat': 27.9,
#   'Lng': 102.26,
#   'Max Temp': 62.13,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 0.47,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'raton',
#   'Lat': 36.9,
#   'Lng': -104.44,
#   'Max Temp': 48.99,
#   'Humidity': 42,
#   'Cloudiness': 1,
#   'Wind Speed': 13.87,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'longyearbyen',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 30.2,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'SJ',
#   'Current Description': 'broken clouds'},
#  {'City': 'tiksi',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': 4.69,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 30.51,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'quang ngai',
#   'Lat': 15.12,
#   'Lng': 108.8,
#   'Max Temp': 75.63,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 1.77,
#   'Country': 'VN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'geraldton',
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 62.6,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 42.8,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'san quintin',
#   'Lat': 30.48,
#   'Lng': -115.95,
#   'Max Temp': 70.07,
#   'Humidity': 60,
#   'Cloudiness': 63,
#   'Wind Speed': 12.06,
#   'Country': 'MX',
#   'Current Description': 'broken clouds'},
#  {'City': 'havre-saint-pierre',
#   'Lat': 50.23,
#   'Lng': -63.6,
#   'Max Temp': 39.2,
#   'Humidity': 44,
#   'Cloudiness': 20,
#   'Wind Speed': 14.99,
#   'Country': 'CA',
#   'Current Description': 'few clouds'},
#  {'City': 'bethel',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 52,
#   'Humidity': 48,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'kahului',
#   'Lat': 20.89,
#   'Lng': -156.47,
#   'Max Temp': 87.8,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'cape town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 63,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'ZA',
#   'Current Description': 'few clouds'},
#  {'City': 'beroroha',
#   'Lat': -21.67,
#   'Lng': 45.17,
#   'Max Temp': 74.95,
#   'Humidity': 56,
#   'Cloudiness': 98,
#   'Wind Speed': 11.23,
#   'Country': 'MG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'mahebourg',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'MU',
#   'Current Description': 'shower rain'},
#  {'City': 'chokurdakh',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': 6.03,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 9.89,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'souillac',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'MU',
#   'Current Description': 'shower rain'},
#  {'City': 'iqaluit',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 8.6,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Current Description': 'few clouds'},
#  {'City': 'qasigiannguit',
#   'Lat': 68.82,
#   'Lng': -51.19,
#   'Max Temp': 15.8,
#   'Humidity': 52,
#   'Cloudiness': 54,
#   'Wind Speed': 6.93,
#   'Country': 'GL',
#   'Current Description': 'broken clouds'},
#  {'City': 'bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 46.99,
#   'Humidity': 97,
#   'Cloudiness': 36,
#   'Wind Speed': 8.86,
#   'Country': 'NZ',
#   'Current Description': 'scattered clouds'},
#  {'City': 'sola',
#   'Lat': -13.88,
#   'Lng': 167.55,
#   'Max Temp': 79.83,
#   'Humidity': 82,
#   'Cloudiness': 5,
#   'Wind Speed': 18.1,
#   'Country': 'VU',
#   'Current Description': 'light rain'},
#  {'City': 'portland',
#   'Lat': 45.52,
#   'Lng': -122.68,
#   'Max Temp': 46,
#   'Humidity': 28,
#   'Cloudiness': 20,
#   'Wind Speed': 17.22,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'saint-ambroise',
#   'Lat': 48.55,
#   'Lng': -71.33,
#   'Max Temp': 37.4,
#   'Humidity': 40,
#   'Cloudiness': 20,
#   'Wind Speed': 17.22,
#   'Country': 'CA',
#   'Current Description': 'few clouds'},
#  {'City': 'mount gambier',
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Max Temp': 41,
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'berlevag',
#   'Lat': 70.86,
#   'Lng': 29.09,
#   'Max Temp': 33.8,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'NO',
#   'Current Description': 'broken clouds'},
#  {'City': 'jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 46,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'leningradskiy',
#   'Lat': 69.38,
#   'Lng': 178.42,
#   'Max Temp': 23.5,
#   'Humidity': 89,
#   'Cloudiness': 49,
#   'Wind Speed': 6.11,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'marsa matruh',
#   'Lat': 31.35,
#   'Lng': 27.25,
#   'Max Temp': 73.4,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Country': 'EG',
#   'Current Description': 'scattered clouds'},
#  {'City': 'halifax',
#   'Lat': 44.65,
#   'Lng': -63.57,
#   'Max Temp': 46.99,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'saint-philippe',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 69.8,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'RE',
#   'Current Description': 'clear sky'},
#  {'City': 'hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 82.98,
#   'Humidity': 71,
#   'Cloudiness': 27,
#   'Wind Speed': 5.39,
#   'Country': 'MV',
#   'Current Description': 'scattered clouds'},
#  {'City': 'olafsvik',
#   'Lat': 64.89,
#   'Lng': -23.71,
#   'Max Temp': 42.75,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 27.51,
#   'Country': 'IS',
#   'Current Description': 'overcast clouds'},
#  {'City': 'hamilton',
#   'Lat': 39.18,
#   'Lng': -84.53,
#   'Max Temp': 54,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'eldorado',
#   'Lat': -23.79,
#   'Lng': -54.28,
#   'Max Temp': 88.41,
#   'Humidity': 49,
#   'Cloudiness': 86,
#   'Wind Speed': 1.95,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 49,
#   'Wind Speed': 11.41,
#   'Country': 'CK',
#   'Current Description': 'light rain'},
#  {'City': 'kodiak',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 48.2,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 17.22,
#   'Country': 'US',
#   'Current Description': 'mist'},
#  {'City': 'vestmannaeyjar',
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Max Temp': 42.8,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'IS',
#   'Current Description': 'broken clouds'},
#  {'City': 'kandrian',
#   'Lat': -6.22,
#   'Lng': 149.55,
#   'Max Temp': 77.5,
#   'Humidity': 82,
#   'Cloudiness': 85,
#   'Wind Speed': 4.43,
#   'Country': 'PG',
#   'Current Description': 'light rain'},
#  {'City': 'nuuk',
#   'Lat': 64.18,
#   'Lng': -51.72,
#   'Max Temp': 26.6,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 12.75,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'sitka',
#   'Lat': 57.05,
#   'Lng': -135.33,
#   'Max Temp': 42.8,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'plattsburgh',
#   'Lat': 44.7,
#   'Lng': -73.45,
#   'Max Temp': 42.8,
#   'Humidity': 48,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'presidencia roque saenz pena',
#   'Lat': -26.79,
#   'Lng': -60.44,
#   'Max Temp': 95.36,
#   'Humidity': 36,
#   'Cloudiness': 88,
#   'Wind Speed': 6.58,
#   'Country': 'AR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'lyubim',
#   'Lat': 58.36,
#   'Lng': 40.68,
#   'Max Temp': 35.96,
#   'Humidity': 90,
#   'Cloudiness': 77,
#   'Wind Speed': 4.45,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'uthal',
#   'Lat': 25.81,
#   'Lng': 66.62,
#   'Max Temp': 72.48,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 0.56,
#   'Country': 'PK',
#   'Current Description': 'clear sky'},
#  {'City': 'nouadhibou',
#   'Lat': 20.93,
#   'Lng': -17.03,
#   'Max Temp': 75.2,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 12.75,
#   'Country': 'MR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'shenjiamen',
#   'Lat': 29.96,
#   'Lng': 122.3,
#   'Max Temp': 63.79,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 5.21,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'bulungu',
#   'Lat': -4.55,
#   'Lng': 18.6,
#   'Max Temp': 73.74,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.35,
#   'Country': 'CD',
#   'Current Description': 'overcast clouds'},
#  {'City': 'narsaq',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 39.2,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 18.34,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 6.35,
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 9.93,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'port lincoln',
#   'Lat': -34.73,
#   'Lng': 135.87,
#   'Max Temp': 51.84,
#   'Humidity': 63,
#   'Cloudiness': 60,
#   'Wind Speed': 15.88,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'kanniyakumari',
#   'Lat': 8.08,
#   'Lng': 77.57,
#   'Max Temp': 79.38,
#   'Humidity': 80,
#   'Cloudiness': 85,
#   'Wind Speed': 14.54,
#   'Country': 'IN',
#   'Current Description': 'light rain'},
#  {'City': 'nova russas',
#   'Lat': -4.71,
#   'Lng': -40.56,
#   'Max Temp': 95.76,
#   'Humidity': 25,
#   'Cloudiness': 66,
#   'Wind Speed': 6.35,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'potiskum',
#   'Lat': 11.71,
#   'Lng': 11.07,
#   'Max Temp': 85.44,
#   'Humidity': 20,
#   'Cloudiness': 90,
#   'Wind Speed': 11.05,
#   'Country': 'NG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'guerrero negro',
#   'Lat': 27.98,
#   'Lng': -114.06,
#   'Max Temp': 72.75,
#   'Humidity': 59,
#   'Cloudiness': 50,
#   'Wind Speed': 16.89,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds'},
#  {'City': 'zychlin',
#   'Lat': 52.24,
#   'Lng': 19.63,
#   'Max Temp': 52,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Country': 'PL',
#   'Current Description': 'clear sky'},
#  {'City': 'yellowknife',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 30,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'kawalu',
#   'Lat': -7.38,
#   'Lng': 108.21,
#   'Max Temp': 72.73,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.04,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'oceanside',
#   'Lat': 33.2,
#   'Lng': -117.38,
#   'Max Temp': 69.01,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'spornoye',
#   'Lat': 50.84,
#   'Lng': 37.29,
#   'Max Temp': 48.2,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'burnie',
#   'Lat': -41.07,
#   'Lng': 145.92,
#   'Max Temp': 41,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 8.99,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'carutapera',
#   'Lat': -1.2,
#   'Lng': -46.02,
#   'Max Temp': 83.5,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 7.74,
#   'Country': 'BR',
#   'Current Description': 'moderate rain'},
#  {'City': 'tynda',
#   'Lat': 55.17,
#   'Lng': 124.72,
#   'Max Temp': 23.95,
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 1.54,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'cabo san lucas',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 93.2,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Country': 'MX',
#   'Current Description': 'few clouds'},
#  {'City': 'husavik',
#   'Lat': 66.04,
#   'Lng': -17.34,
#   'Max Temp': 42.8,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'IS',
#   'Current Description': 'broken clouds'},
#  {'City': 'touros',
#   'Lat': -5.2,
#   'Lng': -35.46,
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'norman wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 21.2,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 8.37,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'pumiao',
#   'Lat': 22.75,
#   'Lng': 108.48,
#   'Max Temp': 66.2,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 3.83,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 26.6,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'klaksvik',
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'FO',
#   'Current Description': 'clear sky'},
#  {'City': 'lieksa',
#   'Lat': 63.32,
#   'Lng': 30.02,
#   'Max Temp': 36.23,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 7.96,
#   'Country': 'FI',
#   'Current Description': 'overcast clouds'},
#  {'City': 'durban',
#   'Lat': -29.86,
#   'Lng': 31.03,
#   'Max Temp': 70,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'saldanha',
#   'Lat': -33.01,
#   'Lng': 17.94,
#   'Max Temp': 60.8,
#   'Humidity': 72,
#   'Cloudiness': 47,
#   'Wind Speed': 9.17,
#   'Country': 'ZA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'cockburn town',
#   'Lat': 21.46,
#   'Lng': -71.14,
#   'Max Temp': 83.48,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 25.32,
#   'Country': 'TC',
#   'Current Description': 'overcast clouds'},
#  {'City': 'port alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 65.71,
#   'Humidity': 80,
#   'Cloudiness': 93,
#   'Wind Speed': 2.55,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'moerai',
#   'Lat': -22.43,
#   'Lng': -151.33,
#   'Max Temp': 72.41,
#   'Humidity': 79,
#   'Cloudiness': 52,
#   'Wind Speed': 21.97,
#   'Country': 'PF',
#   'Current Description': 'broken clouds'},
#  {'City': 'monkey bay',
#   'Lat': -14.07,
#   'Lng': 34.92,
#   'Max Temp': 80.47,
#   'Humidity': 63,
#   'Cloudiness': 84,
#   'Wind Speed': 8.93,
#   'Country': 'MW',
#   'Current Description': 'broken clouds'},
#  {'City': 'cidreira',
#   'Lat': -30.18,
#   'Lng': -50.21,
#   'Max Temp': 70.41,
#   'Humidity': 84,
#   'Cloudiness': 3,
#   'Wind Speed': 22.32,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'suluq',
#   'Lat': 31.67,
#   'Lng': 20.25,
#   'Max Temp': 69.89,
#   'Humidity': 78,
#   'Cloudiness': 4,
#   'Wind Speed': 5.1,
#   'Country': 'LY',
#   'Current Description': 'clear sky'},
#  {'City': 'sept-iles',
#   'Lat': 50.2,
#   'Lng': -66.38,
#   'Max Temp': 37,
#   'Humidity': 43,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'parrita',
#   'Lat': 9.52,
#   'Lng': -84.32,
#   'Max Temp': 75.2,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'CR',
#   'Current Description': 'broken clouds'},
#  {'City': 'sinnamary',
#   'Lat': 5.38,
#   'Lng': -52.95,
#   'Max Temp': 84.33,
#   'Humidity': 71,
#   'Cloudiness': 22,
#   'Wind Speed': 10.02,
#   'Country': 'GF',
#   'Current Description': 'few clouds'},
#  {'City': 'mogocha',
#   'Lat': 53.73,
#   'Lng': 119.77,
#   'Max Temp': 28.98,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 64.4,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'madison',
#   'Lat': 34.73,
#   'Lng': -86.57,
#   'Max Temp': 70,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'lesozavodsk',
#   'Lat': 45.48,
#   'Lng': 133.42,
#   'Max Temp': 34.63,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind Speed': 1.83,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'labuhan',
#   'Lat': -6.88,
#   'Lng': 112.21,
#   'Max Temp': 79.52,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 8.81,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 13.87,
#   'Humidity': 76,
#   'Cloudiness': 63,
#   'Wind Speed': 4.18,
#   'Country': 'GL',
#   'Current Description': 'broken clouds'},
#  {'City': 'bereda',
#   'Lat': 43.27,
#   'Lng': -7.54,
#   'Max Temp': 44.01,
#   'Humidity': 98,
#   'Cloudiness': 72,
#   'Wind Speed': 10,
#   'Country': 'ES',
#   'Current Description': 'broken clouds'},
#  {'City': 'tuatapere',
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Max Temp': 46.99,
#   'Humidity': 96,
#   'Cloudiness': 82,
#   'Wind Speed': 1.01,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'buzmeyin',
#   'Lat': 38.05,
#   'Lng': 58.21,
#   'Max Temp': 57.2,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'TM',
#   'Current Description': 'clear sky'},
#  {'City': 'vila velha',
#   'Lat': -20.33,
#   'Lng': -40.29,
#   'Max Temp': 75,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'BR',
#   'Current Description': 'light rain'},
#  {'City': 'katherine',
#   'Lat': -14.47,
#   'Lng': 132.27,
#   'Max Temp': 78.8,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'provideniya',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 33.21,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.65,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 78.93,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 20,
#   'Country': 'PF',
#   'Current Description': 'clear sky'},
#  {'City': 'erenhot',
#   'Lat': 43.65,
#   'Lng': 111.98,
#   'Max Temp': 44.42,
#   'Humidity': 54,
#   'Cloudiness': 29,
#   'Wind Speed': 15.19,
#   'Country': 'CN',
#   'Current Description': 'scattered clouds'},
#  {'City': 'bambous virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'MU',
#   'Current Description': 'shower rain'},
#  {'City': 'ca mau',
#   'Lat': 9.18,
#   'Lng': 105.15,
#   'Max Temp': 75.47,
#   'Humidity': 95,
#   'Cloudiness': 52,
#   'Wind Speed': 3.49,
#   'Country': 'VN',
#   'Current Description': 'broken clouds'},
#  {'City': 'kuryk',
#   'Lat': 43.2,
#   'Lng': 51.65,
#   'Max Temp': 59.47,
#   'Humidity': 93,
#   'Cloudiness': 78,
#   'Wind Speed': 4.14,
#   'Country': 'KZ',
#   'Current Description': 'broken clouds'},
#  {'City': 'pozo colorado',
#   'Lat': -23.49,
#   'Lng': -58.8,
#   'Max Temp': 102.47,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 8.66,
#   'Country': 'PY',
#   'Current Description': 'clear sky'},
#  {'City': 'sur',
#   'Lat': 22.57,
#   'Lng': 59.53,
#   'Max Temp': 72.9,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 5.21,
#   'Country': 'OM',
#   'Current Description': 'clear sky'},
#  {'City': 'cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 13.01,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.16,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'vao',
#   'Lat': -22.67,
#   'Lng': 167.48,
#   'Max Temp': 72.18,
#   'Humidity': 78,
#   'Cloudiness': 12,
#   'Wind Speed': 12.35,
#   'Country': 'NC',
#   'Current Description': 'few clouds'},
#  {'City': 'tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 23,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 23.04,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'coolum beach',
#   'Lat': -26.53,
#   'Lng': 153.1,
#   'Max Temp': 72,
#   'Humidity': 88,
#   'Cloudiness': 13,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Current Description': 'few clouds'},
#  {'City': 'mount isa',
#   'Lat': -20.73,
#   'Lng': 139.5,
#   'Max Temp': 69.8,
#   'Humidity': 32,
#   'Cloudiness': 100,
#   'Wind Speed': 11.41,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'pochutla',
#   'Lat': 15.74,
#   'Lng': -96.47,
#   'Max Temp': 91.4,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 6.69,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds'},
#  {'City': 'pisco',
#   'Lat': -13.7,
#   'Lng': -76.22,
#   'Max Temp': 69.8,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 17.22,
#   'Country': 'PE',
#   'Current Description': 'clear sky'},
#  {'City': 'port said',
#   'Lat': 31.26,
#   'Lng': 32.28,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Country': 'EG',
#   'Current Description': 'clear sky'},
#  {'City': 'honiara',
#   'Lat': -9.43,
#   'Lng': 159.95,
#   'Max Temp': 73.4,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'SB',
#   'Current Description': 'broken clouds'},
#  {'City': 'saskylakh',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': 8.87,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 12.17,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'mayumba',
#   'Lat': -3.43,
#   'Lng': 10.66,
#   'Max Temp': 77.47,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 7.96,
#   'Country': 'GA',
#   'Current Description': 'light rain'},
#  {'City': 'vostok',
#   'Lat': 46.49,
#   'Lng': 135.88,
#   'Max Temp': 27.91,
#   'Humidity': 99,
#   'Cloudiness': 41,
#   'Wind Speed': 1.99,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'goure',
#   'Lat': 13.98,
#   'Lng': 10.27,
#   'Max Temp': 84.51,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 10.11,
#   'Country': 'NE',
#   'Current Description': 'clear sky'},
#  {'City': 'beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.32,
#   'Max Temp': 29.8,
#   'Humidity': 94,
#   'Cloudiness': 58,
#   'Wind Speed': 3.38,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'zhigansk',
#   'Lat': 66.77,
#   'Lng': 123.37,
#   'Max Temp': -1.91,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 5.23,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'hofn',
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 43.93,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 13.44,
#   'Country': 'IS',
#   'Current Description': 'overcast clouds'},
#  {'City': 'fukue',
#   'Lat': 32.69,
#   'Lng': 128.84,
#   'Max Temp': 65.52,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind Speed': 11.25,
#   'Country': 'JP',
#   'Current Description': 'clear sky'},
#  {'City': 'hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 37.6,
#   'Humidity': 69,
#   'Cloudiness': 2,
#   'Wind Speed': 4.23,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'tacuarembo',
#   'Lat': -31.73,
#   'Lng': -55.98,
#   'Max Temp': 82.99,
#   'Humidity': 68,
#   'Cloudiness': 18,
#   'Wind Speed': 9.01,
#   'Country': 'UY',
#   'Current Description': 'moderate rain'},
#  {'City': 'port elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 62.6,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 6.93,
#   'Country': 'ZA',
#   'Current Description': 'light rain'},
#  {'City': 'lagoa',
#   'Lat': 39.05,
#   'Lng': -27.98,
#   'Max Temp': 64.09,
#   'Humidity': 63,
#   'Cloudiness': 23,
#   'Wind Speed': 6.04,
#   'Country': 'PT',
#   'Current Description': 'few clouds'},
#  {'City': 'aripuana',
#   'Lat': -9.17,
#   'Lng': -60.63,
#   'Max Temp': 90.16,
#   'Humidity': 50,
#   'Cloudiness': 79,
#   'Wind Speed': 2.24,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 62.6,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'CL',
#   'Current Description': 'broken clouds'},
#  {'City': 'senador guiomard',
#   'Lat': -10.15,
#   'Lng': -67.74,
#   'Max Temp': 91.4,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'BR',
#   'Current Description': 'shower rain'},
#  {'City': 'sapele',
#   'Lat': 5.89,
#   'Lng': 5.68,
#   'Max Temp': 76.84,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 3.58,
#   'Country': 'NG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'opuwo',
#   'Lat': -18.06,
#   'Lng': 13.84,
#   'Max Temp': 72.3,
#   'Humidity': 36,
#   'Cloudiness': 19,
#   'Wind Speed': 5.32,
#   'Country': 'NA',
#   'Current Description': 'few clouds'},
#  {'City': 'kloulklubed',
#   'Lat': 7.04,
#   'Lng': 134.26,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 3.42,
#   'Country': 'PW',
#   'Current Description': 'broken clouds'},
#  {'City': 'nara',
#   'Lat': 34.69,
#   'Lng': 135.8,
#   'Max Temp': 51.01,
#   'Humidity': 89,
#   'Cloudiness': 68,
#   'Wind Speed': 1.39,
#   'Country': 'JP',
#   'Current Description': 'broken clouds'},
#  {'City': 'barinas',
#   'Lat': 8.62,
#   'Lng': -70.21,
#   'Max Temp': 85.84,
#   'Humidity': 71,
#   'Cloudiness': 57,
#   'Wind Speed': 5.28,
#   'Country': 'VE',
#   'Current Description': 'broken clouds'},
#  {'City': 'bentiu',
#   'Lat': 9.23,
#   'Lng': 29.83,
#   'Max Temp': 79.81,
#   'Humidity': 57,
#   'Cloudiness': 2,
#   'Wind Speed': 0.87,
#   'Country': 'SS',
#   'Current Description': 'clear sky'},
#  {'City': 'coquimbo',
#   'Lat': -29.95,
#   'Lng': -71.34,
#   'Max Temp': 66.2,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'vila franca do campo',
#   'Lat': 37.72,
#   'Lng': -25.43,
#   'Max Temp': 62.6,
#   'Humidity': 72,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Country': 'PT',
#   'Current Description': 'few clouds'},
#  {'City': 'coihaique',
#   'Lat': -45.58,
#   'Lng': -72.07,
#   'Max Temp': 51.8,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'CL',
#   'Current Description': 'broken clouds'},
#  {'City': 'helong',
#   'Lat': 42.54,
#   'Lng': 129,
#   'Max Temp': 37.24,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'alyangula',
#   'Lat': -13.85,
#   'Lng': 136.42,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'AU',
#   'Current Description': 'light intensity shower rain'},
#  {'City': 'thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 26.6,
#   'Humidity': 53,
#   'Cloudiness': 90,
#   'Wind Speed': 13.87,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'bambanglipuro',
#   'Lat': -7.95,
#   'Lng': 110.28,
#   'Max Temp': 77.65,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 6.76,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'talnakh',
#   'Lat': 69.49,
#   'Lng': 88.4,
#   'Max Temp': 10.4,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 13.42,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'san patricio',
#   'Lat': 28.02,
#   'Lng': -97.52,
#   'Max Temp': 84,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'torbay',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 44.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 24.16,
#   'Country': 'CA',
#   'Current Description': 'mist'},
#  {'City': 'carnarvon',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 84,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 3.62,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'orlik',
#   'Lat': 52.52,
#   'Lng': 99.83,
#   'Max Temp': 1.78,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 4.65,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'altay',
#   'Lat': 47.87,
#   'Lng': 88.12,
#   'Max Temp': 26.6,
#   'Humidity': 72,
#   'Cloudiness': 51,
#   'Wind Speed': 1.88,
#   'Country': 'CN',
#   'Current Description': 'broken clouds'},
#  {'City': 'myitkyina',
#   'Lat': 25.38,
#   'Lng': 97.4,
#   'Max Temp': 69.67,
#   'Humidity': 94,
#   'Cloudiness': 25,
#   'Wind Speed': 1.59,
#   'Country': 'MM',
#   'Current Description': 'scattered clouds'},
#  {'City': 'port hedland',
#   'Lat': -20.32,
#   'Lng': 118.57,
#   'Max Temp': 69.8,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.17,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'new norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 42.01,
#   'Humidity': 71,
#   'Cloudiness': 3,
#   'Wind Speed': 1.77,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'lavrentiya',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 33.26,
#   'Humidity': 91,
#   'Cloudiness': 95,
#   'Wind Speed': 8.99,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'hukuntsi',
#   'Lat': -24,
#   'Lng': 21.75,
#   'Max Temp': 80.13,
#   'Humidity': 33,
#   'Cloudiness': 100,
#   'Wind Speed': 5.91,
#   'Country': 'BW',
#   'Current Description': 'light rain'},
#  {'City': 'mopti',
#   'Lat': 14.67,
#   'Lng': -4,
#   'Max Temp': 87.13,
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 8.5,
#   'Country': 'ML',
#   'Current Description': 'clear sky'},
#  {'City': 'san cristobal',
#   'Lat': 7.77,
#   'Lng': -72.22,
#   'Max Temp': 86,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'VE',
#   'Current Description': 'scattered clouds'},
#  {'City': 'kalmunai',
#   'Lat': 7.42,
#   'Lng': 81.82,
#   'Max Temp': 80.6,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 0.67,
#   'Country': 'LK',
#   'Current Description': 'overcast clouds'},
#  {'City': 'dudinka',
#   'Lat': 69.41,
#   'Lng': 86.18,
#   'Max Temp': 10.4,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 13.42,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'sheopur',
#   'Lat': 25.67,
#   'Lng': 76.7,
#   'Max Temp': 73.17,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 3.58,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'nadym',
#   'Lat': 65.53,
#   'Lng': 72.52,
#   'Max Temp': 15.08,
#   'Humidity': 96,
#   'Cloudiness': 98,
#   'Wind Speed': 12.82,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'yakeshi',
#   'Lat': 49.28,
#   'Lng': 120.73,
#   'Max Temp': 27.37,
#   'Humidity': 92,
#   'Cloudiness': 86,
#   'Wind Speed': 4.83,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 18.12,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 13.71,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'hilton head island',
#   'Lat': 32.22,
#   'Lng': -80.75,
#   'Max Temp': 78.8,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 7.83,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'sao joao da barra',
#   'Lat': -21.64,
#   'Lng': -41.05,
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Country': 'BR',
#   'Current Description': 'light rain'},
#  {'City': 'vardo',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 37.4,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 20.8,
#   'Country': 'NO',
#   'Current Description': 'broken clouds'},
#  {'City': 'arraial do cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 73.4,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'luderitz',
#   'Lat': -26.65,
#   'Lng': 15.16,
#   'Max Temp': 66.2,
#   'Humidity': 50,
#   'Cloudiness': 71,
#   'Wind Speed': 24.94,
#   'Country': 'NA',
#   'Current Description': 'broken clouds'},
#  {'City': 'sheltozero',
#   'Lat': 61.37,
#   'Lng': 35.37,
#   'Max Temp': 34.99,
#   'Humidity': 86,
#   'Cloudiness': 60,
#   'Wind Speed': 6.02,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'castro',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 72.75,
#   'Humidity': 72,
#   'Cloudiness': 1,
#   'Wind Speed': 2.77,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'pekan',
#   'Lat': 3.48,
#   'Lng': 103.4,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Country': 'MY',
#   'Current Description': 'few clouds'},
#  {'City': 'anadyr',
#   'Lat': 64.75,
#   'Lng': 177.48,
#   'Max Temp': 23,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'port macquarie',
#   'Lat': -31.43,
#   'Lng': 152.92,
#   'Max Temp': 61,
#   'Humidity': 91,
#   'Cloudiness': 95,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'salalah',
#   'Lat': 17.02,
#   'Lng': 54.09,
#   'Max Temp': 77,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'OM',
#   'Current Description': 'clear sky'},
#  {'City': 'bireun',
#   'Lat': 5.2,
#   'Lng': 96.7,
#   'Max Temp': 76.89,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 4.65,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'california city',
#   'Lat': 35.13,
#   'Lng': -117.99,
#   'Max Temp': 68,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 33.33,
#   'Country': 'US',
#   'Current Description': 'haze'},
#  {'City': 'isangel',
#   'Lat': -19.55,
#   'Lng': 169.27,
#   'Max Temp': 75.85,
#   'Humidity': 74,
#   'Cloudiness': 7,
#   'Wind Speed': 10.76,
#   'Country': 'VU',
#   'Current Description': 'clear sky'},
#  {'City': 'alim',
#   'Lat': 9.56,
#   'Lng': 122.49,
#   'Max Temp': 77.36,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 17.47,
#   'Country': 'PH',
#   'Current Description': 'light rain'},
#  {'City': 'ekhabi',
#   'Lat': 53.51,
#   'Lng': 142.97,
#   'Max Temp': 39.4,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 19.91,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'isiro',
#   'Lat': 2.77,
#   'Lng': 27.62,
#   'Max Temp': 68.38,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 2.68,
#   'Country': 'CD',
#   'Current Description': 'overcast clouds'},
#  {'City': 'rio gallegos',
#   'Lat': -51.62,
#   'Lng': -69.22,
#   'Max Temp': 57.2,
#   'Humidity': 47,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'AR',
#   'Current Description': 'broken clouds'},
#  {'City': 'murgab',
#   'Lat': 37.5,
#   'Lng': 61.97,
#   'Max Temp': 55.4,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Country': 'TM',
#   'Current Description': 'clear sky'},
#  {'City': 'nivala',
#   'Lat': 63.92,
#   'Lng': 24.97,
#   'Max Temp': 34,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.99,
#   'Country': 'FI',
#   'Current Description': 'overcast clouds'},
#  {'City': 'zheleznodorozhnyy',
#   'Lat': 55.75,
#   'Lng': 38,
#   'Max Temp': 48.2,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'los llanos de aridane',
#   'Lat': 28.66,
#   'Lng': -17.92,
#   'Max Temp': 71.6,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'ES',
#   'Current Description': 'scattered clouds'},
#  {'City': 'koumac',
#   'Lat': -20.57,
#   'Lng': 164.28,
#   'Max Temp': 75.27,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 4.05,
#   'Country': 'NC',
#   'Current Description': 'clear sky'},
#  {'City': 'walvis bay',
#   'Lat': -22.96,
#   'Lng': 14.51,
#   'Max Temp': 60.8,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'NA',
#   'Current Description': 'clear sky'},
#  {'City': 'fort nelson',
#   'Lat': 58.81,
#   'Lng': -122.7,
#   'Max Temp': 21.2,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'namibe',
#   'Lat': -15.2,
#   'Lng': 12.15,
#   'Max Temp': 68.83,
#   'Humidity': 79,
#   'Cloudiness': 52,
#   'Wind Speed': 4.65,
#   'Country': 'AO',
#   'Current Description': 'broken clouds'},
#  {'City': 'chinhoyi',
#   'Lat': -17.37,
#   'Lng': 30.2,
#   'Max Temp': 74.66,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 4.74,
#   'Country': 'ZW',
#   'Current Description': 'clear sky'},
#  {'City': 'kaitangata',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 48,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.25,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'pevek',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 26.78,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 7.36,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'soyo',
#   'Lat': -6.13,
#   'Lng': 12.37,
#   'Max Temp': 77.32,
#   'Humidity': 84,
#   'Cloudiness': 96,
#   'Wind Speed': 10.04,
#   'Country': 'AO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'kaman',
#   'Lat': 27.65,
#   'Lng': 77.27,
#   'Max Temp': 73.89,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 3.53,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'viedma',
#   'Lat': -40.81,
#   'Lng': -63,
#   'Max Temp': 70,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'fuengirola',
#   'Lat': 36.54,
#   'Lng': -4.62,
#   'Max Temp': 66.99,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'ES',
#   'Current Description': 'few clouds'},
#  {'City': 'yerbogachen',
#   'Lat': 61.28,
#   'Lng': 108.01,
#   'Max Temp': 24.06,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.82,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'kaeo',
#   'Lat': -35.1,
#   'Lng': 173.78,
#   'Max Temp': 60.01,
#   'Humidity': 96,
#   'Cloudiness': 28,
#   'Wind Speed': 1.99,
#   'Country': 'NZ',
#   'Current Description': 'scattered clouds'},
#  {'City': 'krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.47,
#   'Max Temp': 4.48,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 9.37,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'panguna',
#   'Lat': -6.32,
#   'Lng': 155.48,
#   'Max Temp': 68.54,
#   'Humidity': 94,
#   'Cloudiness': 26,
#   'Wind Speed': 2.46,
#   'Country': 'PG',
#   'Current Description': 'scattered clouds'},
#  {'City': 'davila',
#   'Lat': 18.47,
#   'Lng': 120.58,
#   'Max Temp': 81.43,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 24.65,
#   'Country': 'PH',
#   'Current Description': 'moderate rain'},
#  {'City': 'aswan',
#   'Lat': 24.09,
#   'Lng': 32.91,
#   'Max Temp': 76.78,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 13.31,
#   'Country': 'EG',
#   'Current Description': 'clear sky'},
#  {'City': 'terekli-mekteb',
#   'Lat': 44.17,
#   'Lng': 45.87,
#   'Max Temp': 62.44,
#   'Humidity': 52,
#   'Cloudiness': 82,
#   'Wind Speed': 6.98,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'iwanai',
#   'Lat': 42.97,
#   'Lng': 140.51,
#   'Max Temp': 45.7,
#   'Humidity': 79,
#   'Cloudiness': 56,
#   'Wind Speed': 4.29,
#   'Country': 'JP',
#   'Current Description': 'broken clouds'},
#  {'City': 'tevriz',
#   'Lat': 57.51,
#   'Lng': 72.4,
#   'Max Temp': 34.59,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.25,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'svetlogorsk',
#   'Lat': 52.63,
#   'Lng': 29.73,
#   'Max Temp': 45.77,
#   'Humidity': 91,
#   'Cloudiness': 47,
#   'Wind Speed': 5.06,
#   'Country': 'BY',
#   'Current Description': 'scattered clouds'},
#  {'City': 'papillion',
#   'Lat': 41.15,
#   'Lng': -96.04,
#   'Max Temp': 32,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'oktyabrskoye',
#   'Lat': 43.06,
#   'Lng': 44.74,
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Cloudiness': 30,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 71.56,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 15.39,
#   'Country': 'UY',
#   'Current Description': 'overcast clouds'},
#  {'City': 'jenbach',
#   'Lat': 47.4,
#   'Lng': 11.74,
#   'Max Temp': 48.2,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'AT',
#   'Current Description': 'few clouds'},
#  {'City': 'darhan',
#   'Lat': 49.49,
#   'Lng': 105.92,
#   'Max Temp': 25.56,
#   'Humidity': 90,
#   'Cloudiness': 89,
#   'Wind Speed': 7.14,
#   'Country': 'MN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'funadhoo',
#   'Lat': 6.15,
#   'Lng': 73.27,
#   'Max Temp': 81.48,
#   'Humidity': 77,
#   'Cloudiness': 100,
# ...
#   'Wind Speed': 4.9,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'dinar',
#   'Lat': 38.06,
#   'Lng': 30.17,
#   'Max Temp': 57.2,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'TR',
#   'Current Description': 'clear sky'},
#  {'City': 'fairbanks',
#   'Lat': 64.84,
#   'Lng': -147.72,
#   'Max Temp': 30,
#   'Humidity': 92,
#   'Cloudiness': 20,
#   'Wind Speed': 3.4,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'kieta',
#   'Lat': -6.22,
#   'Lng': 155.63,
#   'Max Temp': 79.07,
#   'Humidity': 74,
#   'Cloudiness': 42,
#   'Wind Speed': 2.06,
#   'Country': 'PG',
#   'Current Description': 'scattered clouds'},
#  {'City': 'temir',
#   'Lat': 49.14,
#   'Lng': 57.13,
#   'Max Temp': 54.59,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 19.17,
#   'Country': 'KZ',
#   'Current Description': 'light rain'},
#  {'City': 'dicabisagan',
#   'Lat': 17.08,
#   'Lng': 122.42,
#   'Max Temp': 80.76,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 15.08,
#   'Country': 'PH',
#   'Current Description': 'moderate rain'},
#  {'City': 'pangody',
#   'Lat': 65.85,
#   'Lng': 74.49,
#   'Max Temp': 10.06,
#   'Humidity': 96,
#   'Cloudiness': 5,
#   'Wind Speed': 10.78,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'tibati',
#   'Lat': 6.47,
#   'Lng': 12.63,
#   'Max Temp': 70.05,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.07,
#   'Country': 'CM',
#   'Current Description': 'overcast clouds'},
#  {'City': 'aromashevo',
#   'Lat': 56.86,
#   'Lng': 68.64,
#   'Max Temp': 36.21,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 6.42,
#   'Country': 'RU',
#   'Current Description': 'light rain'},
#  {'City': 'salgueiro',
#   'Lat': -8.07,
#   'Lng': -39.12,
#   'Max Temp': 96.57,
#   'Humidity': 20,
#   'Cloudiness': 86,
#   'Wind Speed': 6.22,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'warri',
#   'Lat': 5.52,
#   'Lng': 5.75,
#   'Max Temp': 76.78,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 3.4,
#   'Country': 'NG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'methoni',
#   'Lat': 36.82,
#   'Lng': 21.7,
#   'Max Temp': 64.99,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 16.26,
#   'Country': 'GR',
#   'Current Description': 'few clouds'},
#  {'City': 'lodja',
#   'Lat': -3.48,
#   'Lng': 23.43,
#   'Max Temp': 70.79,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.93,
#   'Country': 'CD',
#   'Current Description': 'overcast clouds'},
#  {'City': 'bubaque',
#   'Lat': 11.28,
#   'Lng': -15.83,
#   'Max Temp': 83.88,
#   'Humidity': 80,
#   'Cloudiness': 18,
#   'Wind Speed': 12.01,
#   'Country': 'GW',
#   'Current Description': 'few clouds'},
#  {'City': 'hervey bay',
#   'Lat': -25.3,
#   'Lng': 152.85,
#   'Max Temp': 73.99,
#   'Humidity': 91,
#   'Cloudiness': 1,
#   'Wind Speed': 5.01,
#   'Country': 'AU',
#   'Current Description': 'light rain'},
#  {'City': 'razole',
#   'Lat': 16.48,
#   'Lng': 81.83,
#   'Max Temp': 75.83,
#   'Humidity': 81,
#   'Cloudiness': 9,
#   'Wind Speed': 1.45,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'bassila',
#   'Lat': 9.01,
#   'Lng': 1.67,
#   'Max Temp': 76.89,
#   'Humidity': 59,
#   'Cloudiness': 4,
#   'Wind Speed': 0.87,
#   'Country': 'BJ',
#   'Current Description': 'clear sky'},
#  {'City': 'brora',
#   'Lat': 58.01,
#   'Lng': -3.85,
#   'Max Temp': 48.2,
#   'Humidity': 70,
#   'Cloudiness': 97,
#   'Wind Speed': 10.29,
#   'Country': 'GB',
#   'Current Description': 'overcast clouds'},
#  {'City': 'manaira',
#   'Lat': -7.71,
#   'Lng': -38.15,
#   'Max Temp': 88.57,
#   'Humidity': 24,
#   'Cloudiness': 97,
#   'Wind Speed': 3.76,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'troitsko-pechorsk',
#   'Lat': 62.71,
#   'Lng': 56.2,
#   'Max Temp': 22.06,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.1,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'bom jardim',
#   'Lat': -7.8,
#   'Lng': -35.59,
#   'Max Temp': 78.73,
#   'Humidity': 69,
#   'Cloudiness': 71,
#   'Wind Speed': 12.64,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'ambovombe',
#   'Lat': -25.17,
#   'Lng': 46.08,
#   'Max Temp': 69.42,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 6.31,
#   'Country': 'MG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'hanzhong',
#   'Lat': 33.07,
#   'Lng': 107.03,
#   'Max Temp': 62.31,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 2.64,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'mayna',
#   'Lat': 54.11,
#   'Lng': 47.62,
#   'Max Temp': 35.33,
#   'Humidity': 90,
#   'Cloudiness': 4,
#   'Wind Speed': 10.71,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'abu dhabi',
#   'Lat': 24.47,
#   'Lng': 54.37,
#   'Max Temp': 82.4,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'AE',
#   'Current Description': 'clear sky'},
#  {'City': 'kerema',
#   'Lat': -7.96,
#   'Lng': 145.78,
#   'Max Temp': 76.53,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.8,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'otradnoye',
#   'Lat': 59.78,
#   'Lng': 30.82,
#   'Max Temp': 42.8,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'bom jesus',
#   'Lat': -9.07,
#   'Lng': -44.36,
#   'Max Temp': 84.22,
#   'Humidity': 55,
#   'Cloudiness': 96,
#   'Wind Speed': 3.38,
#   'Country': 'BR',
#   'Current Description': 'light rain'},
#  {'City': 'baykit',
#   'Lat': 61.67,
#   'Lng': 96.37,
#   'Max Temp': 11.66,
#   'Humidity': 92,
#   'Cloudiness': 56,
#   'Wind Speed': 1.21,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'oranjemund',
#   'Lat': -28.55,
#   'Lng': 16.43,
#   'Max Temp': 59.16,
#   'Humidity': 84,
#   'Cloudiness': 35,
#   'Wind Speed': 18.75,
#   'Country': 'NA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'dhidhdhoo',
#   'Lat': 6.88,
#   'Lng': 73.1,
#   'Max Temp': 80.28,
#   'Humidity': 82,
#   'Cloudiness': 96,
#   'Wind Speed': 11.74,
#   'Country': 'MV',
#   'Current Description': 'moderate rain'},
#  {'City': 'auray',
#   'Lat': 47.67,
#   'Lng': -2.99,
#   'Max Temp': 53.01,
#   'Humidity': 76,
#   'Cloudiness': 50,
#   'Wind Speed': 5.99,
#   'Country': 'FR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'ossipee',
#   'Lat': 43.69,
#   'Lng': -71.12,
#   'Max Temp': 50,
#   'Humidity': 55,
#   'Cloudiness': 18,
#   'Wind Speed': 3.58,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'wau',
#   'Lat': 7.7,
#   'Lng': 28,
#   'Max Temp': 78.15,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 4.21,
#   'Country': 'SS',
#   'Current Description': 'overcast clouds'},
#  {'City': 'rajpipla',
#   'Lat': 21.87,
#   'Lng': 73.5,
#   'Max Temp': 76.19,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 3.85,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'khorixas',
#   'Lat': -20.37,
#   'Lng': 14.97,
#   'Max Temp': 71.83,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 8.08,
#   'Country': 'NA',
#   'Current Description': 'clear sky'},
#  {'City': 'bage',
#   'Lat': -31.33,
#   'Lng': -54.11,
#   'Max Temp': 84.2,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'the pas',
#   'Lat': 53.83,
#   'Lng': -101.25,
#   'Max Temp': 26.6,
#   'Humidity': 68,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'jalu',
#   'Lat': 29.03,
#   'Lng': 21.55,
#   'Max Temp': 65.75,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 3.94,
#   'Country': 'LY',
#   'Current Description': 'clear sky'},
#  {'City': 'kajaani',
#   'Lat': 64.23,
#   'Lng': 27.73,
#   'Max Temp': 33.8,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'FI',
#   'Current Description': 'light rain'},
#  {'City': 'harsin',
#   'Lat': 34.27,
#   'Lng': 47.59,
#   'Max Temp': 62.6,
#   'Humidity': 7,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'belle fourche',
#   'Lat': 44.67,
#   'Lng': -103.85,
#   'Max Temp': 17.01,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 12.75,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'muroto',
#   'Lat': 33.28,
#   'Lng': 134.15,
#   'Max Temp': 63.5,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 5.55,
#   'Country': 'JP',
#   'Current Description': 'scattered clouds'},
#  {'City': 'tautira',
#   'Lat': -17.73,
#   'Lng': -149.15,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'PF',
#   'Current Description': 'shower rain'},
#  {'City': 'kavaratti',
#   'Lat': 10.57,
#   'Lng': 72.64,
#   'Max Temp': 81.54,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 8.59,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'cordoba',
#   'Lat': -31.41,
#   'Lng': -64.18,
#   'Max Temp': 64,
#   'Humidity': 48,
#   'Cloudiness': 90,
#   'Wind Speed': 26.4,
#   'Country': 'AR',
#   'Current Description': 'shower rain'},
#  {'City': 'zuwarah',
#   'Lat': 32.93,
#   'Lng': 12.08,
#   'Max Temp': 71.6,
#   'Humidity': 70,
#   'Cloudiness': 72,
#   'Wind Speed': 15.5,
#   'Country': 'LY',
#   'Current Description': 'broken clouds'},
#  {'City': 'samana',
#   'Lat': 19.21,
#   'Lng': -69.34,
#   'Max Temp': 89.6,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Country': 'DO',
#   'Current Description': 'few clouds'},
#  {'City': 'cabedelo',
#   'Lat': -6.98,
#   'Lng': -34.83,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'khovu-aksy',
#   'Lat': 51.13,
#   'Lng': 93.6,
#   'Max Temp': 20.05,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 3.87,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'kolvereid',
#   'Lat': 64.87,
#   'Lng': 11.6,
#   'Max Temp': 46.4,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'NO',
#   'Current Description': 'shower rain'},
#  {'City': 'ormond beach',
#   'Lat': 29.29,
#   'Lng': -81.06,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'turochak',
#   'Lat': 52.26,
#   'Lng': 87.12,
#   'Max Temp': 32.18,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'bakchar',
#   'Lat': 57.02,
#   'Lng': 82.07,
#   'Max Temp': 29.41,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 8.63,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'acapulco',
#   'Lat': 16.86,
#   'Lng': -99.89,
#   'Max Temp': 87.8,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds'},
#  {'City': 'sambava',
#   'Lat': -14.27,
#   'Lng': 50.17,
#   'Max Temp': 71.94,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 9.89,
#   'Country': 'MG',
#   'Current Description': 'clear sky'},
#  {'City': 'pitimbu',
#   'Lat': -7.47,
#   'Lng': -34.81,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 11.41,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'palmer',
#   'Lat': 42.16,
#   'Lng': -72.33,
#   'Max Temp': 52,
#   'Humidity': 46,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'mandalgovi',
#   'Lat': 45.76,
#   'Lng': 106.27,
#   'Max Temp': 25.65,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 25.9,
#   'Country': 'MN',
#   'Current Description': 'clear sky'},
#  {'City': 'inirida',
#   'Lat': 3.87,
#   'Lng': -67.92,
#   'Max Temp': 88.25,
#   'Humidity': 60,
#   'Cloudiness': 25,
#   'Wind Speed': 2.13,
#   'Country': 'CO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'camacha',
#   'Lat': 33.08,
#   'Lng': -16.33,
#   'Max Temp': 68,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 14.99,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'svetlyy',
#   'Lat': 54.67,
#   'Lng': 20.13,
#   'Max Temp': 51.8,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'lakes entrance',
#   'Lat': -37.88,
#   'Lng': 147.98,
#   'Max Temp': 52,
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 11.59,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'saint simons',
#   'Lat': 31.14,
#   'Lng': -81.39,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'alice springs',
#   'Lat': -23.7,
#   'Lng': 133.88,
#   'Max Temp': 59,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'biograd na moru',
#   'Lat': 43.94,
#   'Lng': 15.45,
#   'Max Temp': 57,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'HR',
#   'Current Description': 'clear sky'},
#  {'City': 'haapiti',
#   'Lat': -17.57,
#   'Lng': -149.87,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'PF',
#   'Current Description': 'shower rain'},
#  {'City': 'pedra branca',
#   'Lat': -5.45,
#   'Lng': -39.72,
#   'Max Temp': 90.73,
#   'Humidity': 30,
#   'Cloudiness': 30,
#   'Wind Speed': 8.21,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'airai',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 61.59,
#   'Humidity': 100,
#   'Cloudiness': 97,
#   'Wind Speed': 1.34,
#   'Country': 'TL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'lerum',
#   'Lat': 57.77,
#   'Lng': 12.27,
#   'Max Temp': 52,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Country': 'SE',
#   'Current Description': 'light rain'},
#  {'City': 'boa vista',
#   'Lat': 2.82,
#   'Lng': -60.67,
#   'Max Temp': 96.8,
#   'Humidity': 37,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'evensk',
#   'Lat': 61.95,
#   'Lng': 159.23,
#   'Max Temp': 32.4,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 14.25,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'hwange',
#   'Lat': -18.37,
#   'Lng': 26.5,
#   'Max Temp': 75.31,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 2.17,
#   'Country': 'ZW',
#   'Current Description': 'clear sky'},
#  {'City': 'huanren',
#   'Lat': 41.26,
#   'Lng': 125.37,
#   'Max Temp': 39.18,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 1.07,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'port blair',
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 79.2,
#   'Humidity': 82,
#   'Cloudiness': 48,
#   'Wind Speed': 2.35,
#   'Country': 'IN',
#   'Current Description': 'moderate rain'},
#  {'City': 'timra',
#   'Lat': 62.49,
#   'Lng': 17.33,
#   'Max Temp': 48.2,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 11.41,
#   'Country': 'SE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'bayan',
#   'Lat': 46.08,
#   'Lng': 127.4,
#   'Max Temp': 35.98,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 1.81,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'qaqortoq',
#   'Lat': 60.72,
#   'Lng': -46.03,
#   'Max Temp': 39.2,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 18.34,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'okhotsk',
#   'Lat': 59.38,
#   'Lng': 143.3,
#   'Max Temp': 32.92,
#   'Humidity': 86,
#   'Cloudiness': 94,
#   'Wind Speed': 23.96,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'liberty',
#   'Lat': 31.83,
#   'Lng': -81.5,
#   'Max Temp': 84.99,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'santa cruz',
#   'Lat': -17.8,
#   'Lng': -63.17,
#   'Max Temp': 95,
#   'Humidity': 44,
#   'Cloudiness': 75,
#   'Wind Speed': 25.28,
#   'Country': 'BO',
#   'Current Description': 'broken clouds'},
#  {'City': 'humaita',
#   'Lat': -7.51,
#   'Lng': -63.02,
#   'Max Temp': 91.02,
#   'Humidity': 50,
#   'Cloudiness': 99,
#   'Wind Speed': 3.94,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#        City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    albany  42.60  -73.97     48.99        42           0        5.39
# 1   ushuaia -54.80  -68.30     51.80        50          40        3.36
# 2   college  64.86 -147.80     30.00        85          75        3.42
# 3    hobart -42.88  147.33     44.60        81          75        6.93
# 4   klyuchi  52.27   79.17     38.71        82         100       15.19
# 5     katra  32.98   74.95     59.59        33           0       10.94
# 6  hermanus -34.42   19.23     61.00        79          98       13.62
# 7   shimoda  34.67  138.95     60.96        61         100        6.93
# 8   yugorsk  61.31   63.33     24.91        99          94        2.33
# 9  bengkulu  -3.80  102.27     74.93        89         100        4.18
#
#   Country Current Description
# 0      US           clear sky
# 1      AR    scattered clouds
# 2      US       broken clouds
# 3      AU       broken clouds
# 4      RU          light rain
# 5      IN           clear sky
# 6      ZA     overcast clouds
# 7      JP     overcast clouds
# 8      RU     overcast clouds
# 9      ID     overcast clouds

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
#Set Columns
# new_column_order = ["column2", "column4", "column1"]
# df = df[new_column_order]
column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df.reindex(columns=column_order)
city_data_df.head(10)
# Out:
#        City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    albany      US  42.60  -73.97     48.99        42           0
# 1   ushuaia      AR -54.80  -68.30     51.80        50          40
# 2   college      US  64.86 -147.80     30.00        85          75
# 3    hobart      AU -42.88  147.33     44.60        81          75
# 4   klyuchi      RU  52.27   79.17     38.71        82         100
# 5     katra      IN  32.98   74.95     59.59        33           0
# 6  hermanus      ZA -34.42   19.23     61.00        79          98
# 7   shimoda      JP  34.67  138.95     60.96        61         100
# 8   yugorsk      RU  61.31   63.33     24.91        99          94
# 9  bengkulu      ID  -3.80  102.27     74.93        89         100
#
#    Wind Speed Current Description
# 0        5.39           clear sky
# 1        3.36    scattered clouds
# 2        3.42       broken clouds
# 3        6.93       broken clouds
# 4       15.19          light rain
# 5       10.94           clear sky
# 6       13.62     overcast clouds
# 7        6.93     overcast clouds
# 8        2.33     overcast clouds
# 9        4.18     overcast clouds

# %%
city_data_df.head(10)
# Create the output file (CSV).
output_data_file = "/Users/chelseaconrad/Desktop/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
