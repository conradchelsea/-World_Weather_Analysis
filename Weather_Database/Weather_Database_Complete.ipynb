# %%
# Import the random module.
import random
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 2000.
# %timeit latitudes(2000)
# Out:
# 3.27 ms ± 190 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
# lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
# lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = lat_lngs

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
len(cities)
cities
# Out:
# ['vaini',
#  'lompoc',
#  'butaritari',
#  'ilulissat',
#  'yumen',
#  'gangapur',
#  'san policarpo',
#  'punta arenas',
#  'uarini',
#  'namibe',
#  'kavieng',
#  'sobolevo',
#  'hasaki',
#  'abu dhabi',
#  'chuy',
#  'labrea',
#  'albany',
#  'cueramaro',
#  'cap malheureux',
#  'lorengau',
#  'richards bay',
#  'clyde river',
#  'mys shmidta',
#  'bambous virieux',
#  'ushuaia',
#  'rikitea',
#  'yerbogachen',
#  'hobart',
#  'attawapiskat',
#  'kapaa',
#  'maroua',
#  'helsinge',
#  'porto walter',
#  'skopelos',
#  'pangody',
#  'tuktoyaktuk',
#  'mar del plata',
#  'taolanaro',
#  'faanui',
#  'yellowknife',
#  'bathsheba',
#  'achisay',
#  'solovetskiy',
#  'samorin',
#  'lusambo',
#  'atuona',
#  'ripoll',
#  'ponta do sol',
#  'georgetown',
#  'watsa',
#  'nikolskoye',
#  'jamestown',
#  'cidreira',
#  'linguere',
#  'tres barras',
#  'pizarro',
#  'hambantota',
#  'chardara',
#  'yulara',
#  'avarua',
#  'tsihombe',
#  'paamiut',
#  'tubruq',
#  'taoudenni',
#  'teknaf',
#  'salinas',
#  'buala',
#  'helong',
#  'qaanaaq',
#  'new norfolk',
#  'anton lizardo',
#  'arraial do cabo',
#  'itarema',
#  'cape town',
#  'tamala',
#  'naze',
#  'snasa',
#  'bubaque',
#  'mataura',
#  'port elizabeth',
#  'hithadhoo',
#  'cherskiy',
#  'sao filipe',
#  'east london',
#  'hermanus',
#  'sentyabrskiy',
#  'yenagoa',
#  'puerto ayora',
#  'barentsburg',
#  'laguna',
#  'anadyr',
#  'nantucket',
#  'ladario',
#  'kavaratti',
#  'dikson',
#  'bluff',
#  'chanasma',
#  'raudeberg',
#  'nanortalik',
#  'provideniya',
#  'busselton',
#  'grants',
#  'nouadhibou',
#  'pevek',
#  'katobu',
#  'saint george',
#  'taburi',
#  'tiksi',
#  'edd',
#  'tual',
#  'rawson',
#  'tazovskiy',
#  'belushya guba',
#  'tongliao',
#  'saleaula',
#  'zasosna',
#  'saskylakh',
#  'evensk',
#  'namatanai',
#  'masterton',
#  'sebinkarahisar',
#  'damara',
#  'agva',
#  'nagai',
#  'roald',
#  'illoqqortoormiut',
#  'guerrero negro',
#  'longlac',
#  'kharovsk',
#  'te anau',
#  'santa rosa',
#  'rio grande',
#  'hilo',
#  'lebu',
#  'cooma',
#  'araxa',
#  'harper',
#  'marcona',
#  'iqaluit',
#  'mandalgovi',
#  'port lincoln',
#  'kruisfontein',
#  'kodiak',
#  'praya',
#  'safranbolu',
#  'bow island',
#  'cabo san lucas',
#  'barrow',
#  'alta floresta',
#  'ambajogai',
#  'camopi',
#  'cayenne',
#  'khatanga',
#  'ponta delgada',
#  'santa isabel do rio negro',
#  'beringovskiy',
#  'vanimo',
#  'tarudant',
#  'durg',
#  'saint-philippe',
#  'flinders',
#  'kismayo',
#  'chokurdakh',
#  'ataco',
#  'airai',
#  'ribeira grande',
#  'englewood',
#  'bargal',
#  'abalak',
#  'tuatapere',
#  'port alfred',
#  'grand centre',
#  'tasiilaq',
#  'dillon',
#  'bredasdorp',
#  'lasa',
#  'barrancas',
#  'voloshka',
#  'wamba',
#  'talnakh',
#  'mabay',
#  'grand river south east',
#  'cap-aux-meules',
#  'conceicao do araguaia',
#  'angoche',
#  'springbok',
#  'tricase',
#  'nelson bay',
#  'nemencine',
#  'sitka',
#  'ancud',
#  'aksarka',
#  'ulladulla',
#  'nishihara',
#  'puro',
#  'jeremie',
#  'kirillov',
#  'victoria',
#  'krasnyy kut',
#  'burica',
#  'singaraja',
#  'kieta',
#  'pisco',
#  'luxor',
#  'hobyo',
#  'souillac',
#  'leningradskiy',
#  'halalo',
#  'broken hill',
#  'klaksvik',
#  'zhezkazgan',
#  'san rafael',
#  'dunedin',
#  'fengcheng',
#  'hamilton',
#  'whittlesea',
#  'vardo',
#  'antofagasta',
#  'thinadhoo',
#  'moree',
#  'pak phanang',
#  'ahipara',
#  'huilong',
#  'longyearbyen',
#  'breves',
#  'thompson',
#  'amahai',
#  'sangar',
#  'meulaboh',
#  'jacobina',
#  'deputatskiy',
#  'sao joao da barra',
#  'beloha',
#  'poronaysk',
#  'castro',
#  'saldanha',
#  'millington',
#  'narsaq',
#  'ribeira brava',
#  'mahebourg',
#  'ostrovnoy',
#  'waipawa',
#  'houston',
#  'sur',
#  'cherlak',
#  'portland',
#  'sept-iles',
#  'skalistyy',
#  'merauke',
#  'arlit',
#  'luderitz',
#  'alenquer',
#  'ust-kamchatsk',
#  'cabedelo',
#  'xichang',
#  'zhanaozen',
#  'bridlington',
#  'carahue',
#  'botro',
#  'tayibe',
#  'leninskoye',
#  'mwanza',
#  'goussainville',
#  'san cristobal',
#  'santa quiteria do maranhao',
#  'coihaique',
#  'palabuhanratu',
#  'asau',
#  'talhar',
#  'cajati',
#  'bengkulu',
#  'kasongo-lunda',
#  'agudos',
#  'lakes entrance',
#  'severo-kurilsk',
#  'quatre cocos',
#  'jaipur hat',
#  'sortland',
#  'poya',
#  'komsomolskiy',
#  'shingu',
#  'margate',
#  'pirgos',
#  'bethel',
#  'dolbeau',
#  'jiazi',
#  'kudahuvadhoo',
#  'lake city',
#  'andevoranto',
#  'gornopravdinsk',
#  'guarapari',
#  'vysokogornyy',
#  'mitsamiouli',
#  'carnarvon',
#  'taipu',
#  'umm kaddadah',
#  'timmins',
#  'deh rawud',
#  'kamenskoye',
#  'colares',
#  'eenhana',
#  'flin flon',
#  'shimoda',
#  'san carlos de bariloche',
#  'tumannyy',
#  'lata',
#  'zhoukou',
#  'touros',
#  'haines junction',
#  'lolua',
#  'trelew',
#  'jalu',
#  'klyuchi',
#  'rapid valley',
#  'samarkand',
#  'imbituba',
#  'amboise',
#  'kaitangata',
#  'chongwe',
#  'kayes',
#  'bennington',
#  'najran',
#  'amderma',
#  'geraldton',
#  'adrar',
#  'fort nelson',
#  'nizhneyansk',
#  'binzhou',
#  'samusu',
#  'plonsk',
#  'kimbe',
#  'kamenka',
#  'katsuura',
#  'lucapa',
#  'hokitika',
#  'lagoa',
#  'kirkwall',
#  'bolgatanga',
#  'hay river',
#  'victor harbor',
#  'berdigestyakh',
#  'micheweni',
#  'san jose',
#  'urazovo',
#  'kutum',
#  'hofn',
#  'arrifes',
#  'tignere',
#  'labutta',
#  'esperance',
#  'oranjestad',
#  'jha jha',
#  'kargasok',
#  'barabinsk',
#  'debre sina',
#  'iranshahr',
#  'upernavik',
#  'tessalit',
#  'bom jardim',
#  'takaka',
#  'batsfjord',
#  'quelimane',
#  'lincoln',
#  'tautira',
#  'nuevo progreso',
#  'luganville',
#  'vaitupu',
#  'oksfjord',
#  'sao jose da coroa grande',
#  'tottori',
#  'constitucion',
#  'aljezur',
#  'pemba',
#  'stony mountain',
#  'arica',
#  'houma',
#  'dicabisagan',
#  'xining',
#  'gwadar',
#  'torbay',
#  'port hardy',
#  'thunder bay',
#  'hirara',
#  'nanakuli',
#  'cao bang',
#  'revda',
#  'serik',
#  'hvolsvollur',
#  'vila velha',
#  'strezhevoy',
#  'guatire',
#  'natchitoches',
#  'bonavista',
#  'charters towers',
#  'udachnyy',
#  'wenling',
#  'rocha',
#  'kjopsvik',
#  'gazni',
#  'chizhou',
#  'tabou',
#  'vao',
#  'nizhneangarsk',
#  'nyurba',
#  'wanning',
#  'lavrentiya',
#  'ndele',
#  'los llanos de aridane',
#  'solnechnyy',
#  'isangel',
#  'ahuimanu',
#  'kadykchan',
#  'pitimbu',
#  'nome',
#  'srednekolymsk',
#  'jurilovca',
#  'bahia blanca',
#  'meyungs',
#  'nuuk',
#  'parrita',
#  'bull savanna',
#  'southbridge',
#  'maumere',
#  'aksum',
#  'rorvik',
#  'sutamarchan',
#  'coquimbo',
#  'bisert',
#  'ventspils',
#  'asyut',
#  'chapais',
#  'svetlogorsk',
#  'fortuna',
#  'lebanon',
#  'manokwari',
#  'baherden',
#  'goderich',
#  'saleilua',
#  'san javier',
#  'sistranda',
#  'zhigansk',
#  'bucerias',
#  'norman wells',
#  'niquelandia',
#  'cockburn town',
#  'hachinohe',
#  'san quintin',
#  'taonan',
#  'bilibino',
#  'gat',
#  'villazon',
#  'miranorte',
#  'kegayli',
#  'zhangye',
#  'tiarei',
#  'casablanca',
#  'kurumkan',
#  'shache',
#  'tianpeng',
#  'riaba',
#  'korla',
#  'shenkursk',
#  'havoysund',
#  'camacha',
#  'praia',
#  'aligudarz',
#  'krasnyy yar',
#  'husavik',
#  'matamoros',
#  'inhambane',
#  'estelle',
#  'mersing',
#  'westpunt',
#  'ballina',
#  'cessnock',
#  'porto novo',
#  'valdivia',
#  'ryotsu',
#  'ilorin',
#  'kihei',
#  'hof',
#  'westport',
#  'canala',
#  'vilyuysk',
#  'gazanjyk',
#  'lashio',
#  'talaya',
#  'llanes',
#  'saravan',
#  'saint-georges',
#  'nokaneng',
#  'patabog',
#  'gogrial',
#  'gizo',
#  'arboletes',
#  'marquette',
#  'meadow lake',
#  'mackay',
#  'vigrestad',
#  'sioux lookout',
#  'biltine',
#  'taltal',
#  'paulba',
#  'sakakah',
#  'passagem franca',
#  'nicoya',
#  'skjervoy',
#  'phuket',
#  'kysyl-syr',
#  'bulgan',
#  'catio',
#  'okhotsk',
#  'west wendover',
#  'banda aceh',
#  'san patricio',
#  'sahuaripa',
#  'mehamn',
#  'dwarka',
#  'esil',
#  'ekhabi',
#  'mazatlan',
#  'baiyin',
#  'ampanihy',
#  'mendota',
#  'smolensk',
#  'ukiah',
#  'carballo',
#  'nola',
#  'palana',
#  'polewali',
#  'la ronge',
#  'temaraia',
#  'linxia',
#  'comodoro rivadavia',
#  'sulangan',
#  'newport',
#  'tacuati',
#  'orito',
#  'diffa',
#  'tezu',
#  'tamiahua',
#  'kirakira',
#  'fare',
#  'goure',
#  'dogondoutchi',
#  'sampit',
#  'sindor',
#  'suarez',
#  'peniche',
#  'farafangana',
#  'pokrovsk-uralskiy',
#  'veraval',
#  'wang saphung',
#  'gravdal',
#  'dalby',
#  'skibbereen',
#  'santo tomas',
#  'barawe',
#  'filadelfia',
#  'sabzevar',
#  'ibra',
#  'san cosme y damian',
#  'dhidhdhoo',
#  'corner brook',
#  'olpad',
#  'rongcheng',
#  'copiapo',
#  'pangnirtung',
#  'aksu',
#  'gweta',
#  'bethanien',
#  'tocopilla',
#  'djibo',
#  'codrington',
#  'sandane',
#  'rio brilhante',
#  'maxixe',
#  'casian',
#  'hailar',
#  'batagay',
#  'doctor pedro p. pena',
#  'tokur',
#  'reshetylivka',
#  'scarborough',
#  'brewster',
#  'qaqortoq',
#  'leshukonskoye',
#  'sidi ali',
#  'cabra',
#  'andros town',
#  'varska',
#  'mount isa',
#  'beaverlodge',
#  'salalah',
#  'misratah',
#  'savonlinna',
#  'pacific grove',
#  'yuxia',
#  'esmeraldas',
#  'leh',
#  'tyulyachi',
#  'bay roberts',
#  'ambon',
#  'ulaanbaatar',
#  'zhigalovo',
#  'flagstaff',
#  'qinhuangdao',
#  'darnah',
#  'calderitas',
#  'sinjai',
#  'oakham',
#  'lodja',
#  'huarmey',
#  'olafsvik',
#  'daxian',
#  'hopelchen',
#  'murgab',
#  'dubai',
#  'sola',
#  'kytlym',
#  'iquique',
#  'ahumada',
#  'cortez',
#  'agirish',
#  'ambodifototra',
#  'muhos',
#  'la rioja',
#  'magistralnyy',
#  'flums',
#  'hihifo',
#  'toftlund',
#  'gangotri',
#  'victoria point',
#  'mayumba',
#  'fairbanks',
#  'vostok',
#  'tahoua',
#  'tres lagoas',
#  'mount gambier',
#  'luanda',
#  'ust-nera',
#  'batangafo',
#  'shubarshi',
#  'zemio',
#  'waitati',
#  'kerema',
#  'kaa-khem',
#  'inirida',
#  'celestun',
#  'mirnyy',
#  'poum',
#  'arkansas city',
#  'abu samrah',
#  'le port',
#  'jalalabad',
#  'yirol',
#  'choctaw',
#  'loa janan',
#  'aleksandrov gay',
#  'luwingu',
#  'liwale',
#  'clarence town',
#  'batemans bay',
#  'shakawe',
#  'wloclawek',
#  'vila franca do campo',
#  'mwingi',
#  'keetmanshoop',
#  'paradise',
#  'miri',
#  'egvekinot',
#  'riyadh',
#  'maniitsoq',
#  'gamba',
#  'rio claro',
#  'opuwo',
#  'cape canaveral',
#  'ketchikan',
#  'banyo',
#  'kyra',
#  'mattru',
#  'padina',
#  'nabire',
#  'chifeng',
#  'aasiaat',
#  'yeppoon',
#  'makakilo city',
#  'walvis bay',
#  'chala',
#  'fort dodge',
#  'mana',
#  'horsham',
#  'itupiranga',
#  'dingle',
#  'umzimvubu',
#  'brigantine',
#  'berlevag',
#  'macapa',
#  'ayan',
#  'grindavik',
#  'pangkalanbuun',
#  'mecca',
#  'mazyr',
#  'axim',
#  'barra do garcas',
#  'tateyama',
#  'lanzhou',
#  'asosa',
#  'trinidad',
#  'iisalmi',
#  'pathein',
#  'koslan',
#  'wewak',
#  'seoul',
#  'naivasha',
#  'manadhoo',
#  'xuddur',
#  'toliary',
#  'awassa',
#  'cananeia',
#  'avera',
#  'beni suef',
#  'youkounkoun',
#  'siloam springs',
#  'sehithwa',
#  'kahului',
#  'dvinskoy',
#  'artyk',
#  'havre-saint-pierre',
#  'oros',
#  'tecoanapa']

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests as req
# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    #retrieve city data
    # Run an API request for each of the cities.
    try:
            # Parse the JSON and retrieve data.
#             print("trying connect")
#             print(city_url)
            city_weather = req.get(city_url).json()
#             print("connected")
            #Parse out the needed data.
#             print("trying lat")
            city_lat = city_weather["coord"]["lat"]
#             print("trying lon")
            city_lng = city_weather["coord"]["lon"]
#             print("trying max")            
            city_max_temp = city_weather["main"]["temp_max"]
#             print("trying humidity")
            city_humidity = city_weather["main"]["humidity"]
#             print("trying clouds")
            city_clouds = city_weather["clouds"]["all"]
#             print("trying speed")
            city_wind = city_weather["wind"]["speed"]
#             print("trying country")
            city_country = city_weather["sys"]["country"]
#             print("trying description")
            city_description = city_weather["weather"][0]["description"]
            # Append the city information into city_data list.
#             print({"City": city,
#                               "Lat": city_lat,
#                               "Lng": city_lng,
#                               "Max Temp": city_max_temp,
#                               "Humidity": city_humidity,
#                               "Cloudiness": city_clouds,
#                               "Wind Speed": city_wind,
#                               "Country": city_country,
#                               "Description" : city_description})
            city_data.append({"City": city,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Country": city_country,
                              "Current Description" : city_description})
    # If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
            pass
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | lompoc
# Processing Record 3 of Set 1 | butaritari
# Processing Record 4 of Set 1 | ilulissat
# Processing Record 5 of Set 1 | yumen
# Processing Record 6 of Set 1 | gangapur
# Processing Record 7 of Set 1 | san policarpo
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | uarini
# Processing Record 10 of Set 1 | namibe
# Processing Record 11 of Set 1 | kavieng
# Processing Record 12 of Set 1 | sobolevo
# Processing Record 13 of Set 1 | hasaki
# Processing Record 14 of Set 1 | abu dhabi
# Processing Record 15 of Set 1 | chuy
# Processing Record 16 of Set 1 | labrea
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | cueramaro
# Processing Record 19 of Set 1 | cap malheureux
# Processing Record 20 of Set 1 | lorengau
# Processing Record 21 of Set 1 | richards bay
# Processing Record 22 of Set 1 | clyde river
# City not found. Skipping...
# Processing Record 23 of Set 1 | mys shmidta
# Processing Record 24 of Set 1 | bambous virieux
# Processing Record 25 of Set 1 | ushuaia
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | yerbogachen
# Processing Record 28 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 29 of Set 1 | attawapiskat
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | maroua
# Processing Record 32 of Set 1 | helsinge
# Processing Record 33 of Set 1 | porto walter
# Processing Record 34 of Set 1 | skopelos
# Processing Record 35 of Set 1 | pangody
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | mar del plata
# City not found. Skipping...
# Processing Record 38 of Set 1 | taolanaro
# Processing Record 39 of Set 1 | faanui
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | bathsheba
# City not found. Skipping...
# Processing Record 42 of Set 1 | achisay
# City not found. Skipping...
# Processing Record 43 of Set 1 | solovetskiy
# Processing Record 44 of Set 1 | samorin
# Processing Record 45 of Set 1 | lusambo
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | ripoll
# Processing Record 48 of Set 1 | ponta do sol
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | watsa
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | cidreira
# Processing Record 4 of Set 2 | linguere
# Processing Record 5 of Set 2 | tres barras
# Processing Record 6 of Set 2 | pizarro
# Processing Record 7 of Set 2 | hambantota
# Processing Record 8 of Set 2 | chardara
# Processing Record 9 of Set 2 | yulara
# Processing Record 10 of Set 2 | avarua
# City not found. Skipping...
# Processing Record 11 of Set 2 | tsihombe
# Processing Record 12 of Set 2 | paamiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | tubruq
# Processing Record 14 of Set 2 | taoudenni
# Processing Record 15 of Set 2 | teknaf
# Processing Record 16 of Set 2 | salinas
# Processing Record 17 of Set 2 | buala
# Processing Record 18 of Set 2 | helong
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | anton lizardo
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | itarema
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | tamala
# Processing Record 26 of Set 2 | naze
# Processing Record 27 of Set 2 | snasa
# Processing Record 28 of Set 2 | bubaque
# Processing Record 29 of Set 2 | mataura
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | cherskiy
# Processing Record 33 of Set 2 | sao filipe
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | hermanus
# City not found. Skipping...
# Processing Record 36 of Set 2 | sentyabrskiy
# Processing Record 37 of Set 2 | yenagoa
# Processing Record 38 of Set 2 | puerto ayora
# City not found. Skipping...
# Processing Record 39 of Set 2 | barentsburg
# Processing Record 40 of Set 2 | laguna
# Processing Record 41 of Set 2 | anadyr
# Processing Record 42 of Set 2 | nantucket
# Processing Record 43 of Set 2 | ladario
# Processing Record 44 of Set 2 | kavaratti
# Processing Record 45 of Set 2 | dikson
# Processing Record 46 of Set 2 | bluff
# Processing Record 47 of Set 2 | chanasma
# Processing Record 48 of Set 2 | raudeberg
# Processing Record 49 of Set 2 | nanortalik
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | busselton
# Processing Record 2 of Set 3 | grants
# Processing Record 3 of Set 3 | nouadhibou
# Processing Record 4 of Set 3 | pevek
# Processing Record 5 of Set 3 | katobu
# Processing Record 6 of Set 3 | saint george
# City not found. Skipping...
# Processing Record 7 of Set 3 | taburi
# Processing Record 8 of Set 3 | tiksi
# Processing Record 9 of Set 3 | edd
# Processing Record 10 of Set 3 | tual
# Processing Record 11 of Set 3 | rawson
# Processing Record 12 of Set 3 | tazovskiy
# City not found. Skipping...
# Processing Record 13 of Set 3 | belushya guba
# Processing Record 14 of Set 3 | tongliao
# City not found. Skipping...
# Processing Record 15 of Set 3 | saleaula
# Processing Record 16 of Set 3 | zasosna
# Processing Record 17 of Set 3 | saskylakh
# Processing Record 18 of Set 3 | evensk
# Processing Record 19 of Set 3 | namatanai
# Processing Record 20 of Set 3 | masterton
# Processing Record 21 of Set 3 | sebinkarahisar
# Processing Record 22 of Set 3 | damara
# City not found. Skipping...
# Processing Record 23 of Set 3 | agva
# Processing Record 24 of Set 3 | nagai
# Processing Record 25 of Set 3 | roald
# City not found. Skipping...
# Processing Record 26 of Set 3 | illoqqortoormiut
# Processing Record 27 of Set 3 | guerrero negro
# City not found. Skipping...
# Processing Record 28 of Set 3 | longlac
# Processing Record 29 of Set 3 | kharovsk
# Processing Record 30 of Set 3 | te anau
# Processing Record 31 of Set 3 | santa rosa
# Processing Record 32 of Set 3 | rio grande
# Processing Record 33 of Set 3 | hilo
# Processing Record 34 of Set 3 | lebu
# Processing Record 35 of Set 3 | cooma
# Processing Record 36 of Set 3 | araxa
# Processing Record 37 of Set 3 | harper
# City not found. Skipping...
# Processing Record 38 of Set 3 | marcona
# Processing Record 39 of Set 3 | iqaluit
# Processing Record 40 of Set 3 | mandalgovi
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | kruisfontein
# Processing Record 43 of Set 3 | kodiak
# Processing Record 44 of Set 3 | praya
# Processing Record 45 of Set 3 | safranbolu
# Processing Record 46 of Set 3 | bow island
# Processing Record 47 of Set 3 | cabo san lucas
# Processing Record 48 of Set 3 | barrow
# Processing Record 49 of Set 3 | alta floresta
# Processing Record 50 of Set 3 | ambajogai
# Processing Record 1 of Set 4 | camopi
# Processing Record 2 of Set 4 | cayenne
# Processing Record 3 of Set 4 | khatanga
# Processing Record 4 of Set 4 | ponta delgada
# Processing Record 5 of Set 4 | santa isabel do rio negro
# Processing Record 6 of Set 4 | beringovskiy
# Processing Record 7 of Set 4 | vanimo
# City not found. Skipping...
# Processing Record 8 of Set 4 | tarudant
# Processing Record 9 of Set 4 | durg
# Processing Record 10 of Set 4 | saint-philippe
# Processing Record 11 of Set 4 | flinders
# Processing Record 12 of Set 4 | kismayo
# Processing Record 13 of Set 4 | chokurdakh
# Processing Record 14 of Set 4 | ataco
# Processing Record 15 of Set 4 | airai
# Processing Record 16 of Set 4 | ribeira grande
# Processing Record 17 of Set 4 | englewood
# City not found. Skipping...
# Processing Record 18 of Set 4 | bargal
# Processing Record 19 of Set 4 | abalak
# Processing Record 20 of Set 4 | tuatapere
# Processing Record 21 of Set 4 | port alfred
# City not found. Skipping...
# Processing Record 22 of Set 4 | grand centre
# Processing Record 23 of Set 4 | tasiilaq
# Processing Record 24 of Set 4 | dillon
# Processing Record 25 of Set 4 | bredasdorp
# Processing Record 26 of Set 4 | lasa
# Processing Record 27 of Set 4 | barrancas
# Processing Record 28 of Set 4 | voloshka
# Processing Record 29 of Set 4 | wamba
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | mabay
# City not found. Skipping...
# Processing Record 32 of Set 4 | grand river south east
# Processing Record 33 of Set 4 | cap-aux-meules
# Processing Record 34 of Set 4 | conceicao do araguaia
# Processing Record 35 of Set 4 | angoche
# Processing Record 36 of Set 4 | springbok
# Processing Record 37 of Set 4 | tricase
# Processing Record 38 of Set 4 | nelson bay
# Processing Record 39 of Set 4 | nemencine
# Processing Record 40 of Set 4 | sitka
# Processing Record 41 of Set 4 | ancud
# Processing Record 42 of Set 4 | aksarka
# Processing Record 43 of Set 4 | ulladulla
# Processing Record 44 of Set 4 | nishihara
# Processing Record 45 of Set 4 | puro
# Processing Record 46 of Set 4 | jeremie
# Processing Record 47 of Set 4 | kirillov
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | krasnyy kut
# City not found. Skipping...
# Processing Record 50 of Set 4 | burica
# Processing Record 1 of Set 5 | singaraja
# Processing Record 2 of Set 5 | kieta
# Processing Record 3 of Set 5 | pisco
# Processing Record 4 of Set 5 | luxor
# Processing Record 5 of Set 5 | hobyo
# Processing Record 6 of Set 5 | souillac
# Processing Record 7 of Set 5 | leningradskiy
# City not found. Skipping...
# Processing Record 8 of Set 5 | halalo
# Processing Record 9 of Set 5 | broken hill
# Processing Record 10 of Set 5 | klaksvik
# Processing Record 11 of Set 5 | zhezkazgan
# Processing Record 12 of Set 5 | san rafael
# Processing Record 13 of Set 5 | dunedin
# Processing Record 14 of Set 5 | fengcheng
# Processing Record 15 of Set 5 | hamilton
# Processing Record 16 of Set 5 | whittlesea
# Processing Record 17 of Set 5 | vardo
# Processing Record 18 of Set 5 | antofagasta
# Processing Record 19 of Set 5 | thinadhoo
# Processing Record 20 of Set 5 | moree
# Processing Record 21 of Set 5 | pak phanang
# Processing Record 22 of Set 5 | ahipara
# Processing Record 23 of Set 5 | huilong
# Processing Record 24 of Set 5 | longyearbyen
# Processing Record 25 of Set 5 | breves
# Processing Record 26 of Set 5 | thompson
# Processing Record 27 of Set 5 | amahai
# Processing Record 28 of Set 5 | sangar
# Processing Record 29 of Set 5 | meulaboh
# Processing Record 30 of Set 5 | jacobina
# Processing Record 31 of Set 5 | deputatskiy
# Processing Record 32 of Set 5 | sao joao da barra
# Processing Record 33 of Set 5 | beloha
# Processing Record 34 of Set 5 | poronaysk
# Processing Record 35 of Set 5 | castro
# Processing Record 36 of Set 5 | saldanha
# Processing Record 37 of Set 5 | millington
# Processing Record 38 of Set 5 | narsaq
# Processing Record 39 of Set 5 | ribeira brava
# Processing Record 40 of Set 5 | mahebourg
# Processing Record 41 of Set 5 | ostrovnoy
# Processing Record 42 of Set 5 | waipawa
# Processing Record 43 of Set 5 | houston
# Processing Record 44 of Set 5 | sur
# Processing Record 45 of Set 5 | cherlak
# Processing Record 46 of Set 5 | portland
# Processing Record 47 of Set 5 | sept-iles
# City not found. Skipping...
# Processing Record 48 of Set 5 | skalistyy
# Processing Record 49 of Set 5 | merauke
# Processing Record 50 of Set 5 | arlit
# Processing Record 1 of Set 6 | luderitz
# Processing Record 2 of Set 6 | alenquer
# City not found. Skipping...
# Processing Record 3 of Set 6 | ust-kamchatsk
# Processing Record 4 of Set 6 | cabedelo
# Processing Record 5 of Set 6 | xichang
# Processing Record 6 of Set 6 | zhanaozen
# Processing Record 7 of Set 6 | bridlington
# Processing Record 8 of Set 6 | carahue
# Processing Record 9 of Set 6 | botro
# City not found. Skipping...
# Processing Record 10 of Set 6 | tayibe
# Processing Record 11 of Set 6 | leninskoye
# Processing Record 12 of Set 6 | mwanza
# Processing Record 13 of Set 6 | goussainville
# Processing Record 14 of Set 6 | san cristobal
# Processing Record 15 of Set 6 | santa quiteria do maranhao
# Processing Record 16 of Set 6 | coihaique
# City not found. Skipping...
# Processing Record 17 of Set 6 | palabuhanratu
# Processing Record 18 of Set 6 | asau
# Processing Record 19 of Set 6 | talhar
# Processing Record 20 of Set 6 | cajati
# Processing Record 21 of Set 6 | bengkulu
# Processing Record 22 of Set 6 | kasongo-lunda
# Processing Record 23 of Set 6 | agudos
# Processing Record 24 of Set 6 | lakes entrance
# Processing Record 25 of Set 6 | severo-kurilsk
# Processing Record 26 of Set 6 | quatre cocos
# City not found. Skipping...
# Processing Record 27 of Set 6 | jaipur hat
# Processing Record 28 of Set 6 | sortland
# Processing Record 29 of Set 6 | poya
# Processing Record 30 of Set 6 | komsomolskiy
# Processing Record 31 of Set 6 | shingu
# Processing Record 32 of Set 6 | margate
# Processing Record 33 of Set 6 | pirgos
# Processing Record 34 of Set 6 | bethel
# City not found. Skipping...
# Processing Record 35 of Set 6 | dolbeau
# Processing Record 36 of Set 6 | jiazi
# Processing Record 37 of Set 6 | kudahuvadhoo
# Processing Record 38 of Set 6 | lake city
# City not found. Skipping...
# Processing Record 39 of Set 6 | andevoranto
# Processing Record 40 of Set 6 | gornopravdinsk
# Processing Record 41 of Set 6 | guarapari
# Processing Record 42 of Set 6 | vysokogornyy
# Processing Record 43 of Set 6 | mitsamiouli
# Processing Record 44 of Set 6 | carnarvon
# Processing Record 45 of Set 6 | taipu
# Processing Record 46 of Set 6 | umm kaddadah
# Processing Record 47 of Set 6 | timmins
# City not found. Skipping...
# Processing Record 48 of Set 6 | deh rawud
# City not found. Skipping...
# Processing Record 49 of Set 6 | kamenskoye
# Processing Record 50 of Set 6 | colares
# Processing Record 1 of Set 7 | eenhana
# Processing Record 2 of Set 7 | flin flon
# Processing Record 3 of Set 7 | shimoda
# Processing Record 4 of Set 7 | san carlos de bariloche
# City not found. Skipping...
# Processing Record 5 of Set 7 | tumannyy
# Processing Record 6 of Set 7 | lata
# Processing Record 7 of Set 7 | zhoukou
# Processing Record 8 of Set 7 | touros
# Processing Record 9 of Set 7 | haines junction
# City not found. Skipping...
# Processing Record 10 of Set 7 | lolua
# Processing Record 11 of Set 7 | trelew
# Processing Record 12 of Set 7 | jalu
# Processing Record 13 of Set 7 | klyuchi
# Processing Record 14 of Set 7 | rapid valley
# Processing Record 15 of Set 7 | samarkand
# Processing Record 16 of Set 7 | imbituba
# Processing Record 17 of Set 7 | amboise
# Processing Record 18 of Set 7 | kaitangata
# Processing Record 19 of Set 7 | chongwe
# Processing Record 20 of Set 7 | kayes
# Processing Record 21 of Set 7 | bennington
# Processing Record 22 of Set 7 | najran
# City not found. Skipping...
# Processing Record 23 of Set 7 | amderma
# Processing Record 24 of Set 7 | geraldton
# Processing Record 25 of Set 7 | adrar
# Processing Record 26 of Set 7 | fort nelson
# City not found. Skipping...
# Processing Record 27 of Set 7 | nizhneyansk
# Processing Record 28 of Set 7 | binzhou
# City not found. Skipping...
# Processing Record 29 of Set 7 | samusu
# Processing Record 30 of Set 7 | plonsk
# Processing Record 31 of Set 7 | kimbe
# Processing Record 32 of Set 7 | kamenka
# Processing Record 33 of Set 7 | katsuura
# Processing Record 34 of Set 7 | lucapa
# Processing Record 35 of Set 7 | hokitika
# Processing Record 36 of Set 7 | lagoa
# Processing Record 37 of Set 7 | kirkwall
# Processing Record 38 of Set 7 | bolgatanga
# Processing Record 39 of Set 7 | hay river
# Processing Record 40 of Set 7 | victor harbor
# Processing Record 41 of Set 7 | berdigestyakh
# Processing Record 42 of Set 7 | micheweni
# Processing Record 43 of Set 7 | san jose
# Processing Record 44 of Set 7 | urazovo
# Processing Record 45 of Set 7 | kutum
# Processing Record 46 of Set 7 | hofn
# Processing Record 47 of Set 7 | arrifes
# Processing Record 48 of Set 7 | tignere
# City not found. Skipping...
# Processing Record 49 of Set 7 | labutta
# Processing Record 50 of Set 7 | esperance
# Processing Record 1 of Set 8 | oranjestad
# Processing Record 2 of Set 8 | jha jha
# Processing Record 3 of Set 8 | kargasok
# Processing Record 4 of Set 8 | barabinsk
# Processing Record 5 of Set 8 | debre sina
# Processing Record 6 of Set 8 | iranshahr
# Processing Record 7 of Set 8 | upernavik
# Processing Record 8 of Set 8 | tessalit
# Processing Record 9 of Set 8 | bom jardim
# Processing Record 10 of Set 8 | takaka
# Processing Record 11 of Set 8 | batsfjord
# Processing Record 12 of Set 8 | quelimane
# Processing Record 13 of Set 8 | lincoln
# Processing Record 14 of Set 8 | tautira
# Processing Record 15 of Set 8 | nuevo progreso
# Processing Record 16 of Set 8 | luganville
# City not found. Skipping...
# Processing Record 17 of Set 8 | vaitupu
# Processing Record 18 of Set 8 | oksfjord
# Processing Record 19 of Set 8 | sao jose da coroa grande
# Processing Record 20 of Set 8 | tottori
# Processing Record 21 of Set 8 | constitucion
# Processing Record 22 of Set 8 | aljezur
# Processing Record 23 of Set 8 | pemba
# Processing Record 24 of Set 8 | stony mountain
# Processing Record 25 of Set 8 | arica
# Processing Record 26 of Set 8 | houma
# Processing Record 27 of Set 8 | dicabisagan
# Processing Record 28 of Set 8 | xining
# Processing Record 29 of Set 8 | gwadar
# Processing Record 30 of Set 8 | torbay
# Processing Record 31 of Set 8 | port hardy
# Processing Record 32 of Set 8 | thunder bay
# Processing Record 33 of Set 8 | hirara
# Processing Record 34 of Set 8 | nanakuli
# Processing Record 35 of Set 8 | cao bang
# Processing Record 36 of Set 8 | revda
# Processing Record 37 of Set 8 | serik
# Processing Record 38 of Set 8 | hvolsvollur
# Processing Record 39 of Set 8 | vila velha
# Processing Record 40 of Set 8 | strezhevoy
# Processing Record 41 of Set 8 | guatire
# Processing Record 42 of Set 8 | natchitoches
# Processing Record 43 of Set 8 | bonavista
# Processing Record 44 of Set 8 | charters towers
# Processing Record 45 of Set 8 | udachnyy
# Processing Record 46 of Set 8 | wenling
# Processing Record 47 of Set 8 | rocha
# Processing Record 48 of Set 8 | kjopsvik
# City not found. Skipping...
# Processing Record 49 of Set 8 | gazni
# Processing Record 50 of Set 8 | chizhou
# Processing Record 1 of Set 9 | tabou
# Processing Record 2 of Set 9 | vao
# Processing Record 3 of Set 9 | nizhneangarsk
# Processing Record 4 of Set 9 | nyurba
# Processing Record 5 of Set 9 | wanning
# Processing Record 6 of Set 9 | lavrentiya
# Processing Record 7 of Set 9 | ndele
# Processing Record 8 of Set 9 | los llanos de aridane
# Processing Record 9 of Set 9 | solnechnyy
# Processing Record 10 of Set 9 | isangel
# Processing Record 11 of Set 9 | ahuimanu
# City not found. Skipping...
# Processing Record 12 of Set 9 | kadykchan
# Processing Record 13 of Set 9 | pitimbu
# Processing Record 14 of Set 9 | nome
# Processing Record 15 of Set 9 | srednekolymsk
# Processing Record 16 of Set 9 | jurilovca
# Processing Record 17 of Set 9 | bahia blanca
# City not found. Skipping...
# Processing Record 18 of Set 9 | meyungs
# Processing Record 19 of Set 9 | nuuk
# Processing Record 20 of Set 9 | parrita
# Processing Record 21 of Set 9 | bull savanna
# Processing Record 22 of Set 9 | southbridge
# Processing Record 23 of Set 9 | maumere
# Processing Record 24 of Set 9 | aksum
# Processing Record 25 of Set 9 | rorvik
# Processing Record 26 of Set 9 | sutamarchan
# Processing Record 27 of Set 9 | coquimbo
# Processing Record 28 of Set 9 | bisert
# Processing Record 29 of Set 9 | ventspils
# Processing Record 30 of Set 9 | asyut
# Processing Record 31 of Set 9 | chapais
# Processing Record 32 of Set 9 | svetlogorsk
# Processing Record 33 of Set 9 | fortuna
# Processing Record 34 of Set 9 | lebanon
# Processing Record 35 of Set 9 | manokwari
# Processing Record 36 of Set 9 | baherden
# Processing Record 37 of Set 9 | goderich
# City not found. Skipping...
# Processing Record 38 of Set 9 | saleilua
# Processing Record 39 of Set 9 | san javier
# Processing Record 40 of Set 9 | sistranda
# Processing Record 41 of Set 9 | zhigansk
# Processing Record 42 of Set 9 | bucerias
# Processing Record 43 of Set 9 | norman wells
# Processing Record 44 of Set 9 | niquelandia
# Processing Record 45 of Set 9 | cockburn town
# Processing Record 46 of Set 9 | hachinohe
# Processing Record 47 of Set 9 | san quintin
# Processing Record 48 of Set 9 | taonan
# Processing Record 49 of Set 9 | bilibino
# Processing Record 50 of Set 9 | gat
# Processing Record 1 of Set 10 | villazon
# City not found. Skipping...
# Processing Record 2 of Set 10 | miranorte
# City not found. Skipping...
# Processing Record 3 of Set 10 | kegayli
# Processing Record 4 of Set 10 | zhangye
# Processing Record 5 of Set 10 | tiarei
# Processing Record 6 of Set 10 | casablanca
# Processing Record 7 of Set 10 | kurumkan
# Processing Record 8 of Set 10 | shache
# Processing Record 9 of Set 10 | tianpeng
# City not found. Skipping...
# Processing Record 10 of Set 10 | riaba
# Processing Record 11 of Set 10 | korla
# Processing Record 12 of Set 10 | shenkursk
# Processing Record 13 of Set 10 | havoysund
# Processing Record 14 of Set 10 | camacha
# Processing Record 15 of Set 10 | praia
# Processing Record 16 of Set 10 | aligudarz
# Processing Record 17 of Set 10 | krasnyy yar
# Processing Record 18 of Set 10 | husavik
# Processing Record 19 of Set 10 | matamoros
# Processing Record 20 of Set 10 | inhambane
# Processing Record 21 of Set 10 | estelle
# Processing Record 22 of Set 10 | mersing
# City not found. Skipping...
# Processing Record 23 of Set 10 | westpunt
# Processing Record 24 of Set 10 | ballina
# Processing Record 25 of Set 10 | cessnock
# Processing Record 26 of Set 10 | porto novo
# Processing Record 27 of Set 10 | valdivia
# Processing Record 28 of Set 10 | ryotsu
# Processing Record 29 of Set 10 | ilorin
# Processing Record 30 of Set 10 | kihei
# Processing Record 31 of Set 10 | hof
# Processing Record 32 of Set 10 | westport
# Processing Record 33 of Set 10 | canala
# Processing Record 34 of Set 10 | vilyuysk
# Processing Record 35 of Set 10 | gazanjyk
# Processing Record 36 of Set 10 | lashio
# Processing Record 37 of Set 10 | talaya
# Processing Record 38 of Set 10 | llanes
# Processing Record 39 of Set 10 | saravan
# Processing Record 40 of Set 10 | saint-georges
# Processing Record 41 of Set 10 | nokaneng
# Processing Record 42 of Set 10 | patabog
# Processing Record 43 of Set 10 | gogrial
# Processing Record 44 of Set 10 | gizo
# Processing Record 45 of Set 10 | arboletes
# Processing Record 46 of Set 10 | marquette
# Processing Record 47 of Set 10 | meadow lake
# Processing Record 48 of Set 10 | mackay
# Processing Record 49 of Set 10 | vigrestad
# Processing Record 50 of Set 10 | sioux lookout
# Processing Record 1 of Set 11 | biltine
# Processing Record 2 of Set 11 | taltal
# Processing Record 3 of Set 11 | paulba
# Processing Record 4 of Set 11 | sakakah
# Processing Record 5 of Set 11 | passagem franca
# Processing Record 6 of Set 11 | nicoya
# Processing Record 7 of Set 11 | skjervoy
# Processing Record 8 of Set 11 | phuket
# Processing Record 9 of Set 11 | kysyl-syr
# Processing Record 10 of Set 11 | bulgan
# Processing Record 11 of Set 11 | catio
# Processing Record 12 of Set 11 | okhotsk
# Processing Record 13 of Set 11 | west wendover
# Processing Record 14 of Set 11 | banda aceh
# Processing Record 15 of Set 11 | san patricio
# Processing Record 16 of Set 11 | sahuaripa
# Processing Record 17 of Set 11 | mehamn
# Processing Record 18 of Set 11 | dwarka
# Processing Record 19 of Set 11 | esil
# Processing Record 20 of Set 11 | ekhabi
# Processing Record 21 of Set 11 | mazatlan
# Processing Record 22 of Set 11 | baiyin
# Processing Record 23 of Set 11 | ampanihy
# Processing Record 24 of Set 11 | mendota
# Processing Record 25 of Set 11 | smolensk
# Processing Record 26 of Set 11 | ukiah
# Processing Record 27 of Set 11 | carballo
# Processing Record 28 of Set 11 | nola
# Processing Record 29 of Set 11 | palana
# Processing Record 30 of Set 11 | polewali
# Processing Record 31 of Set 11 | la ronge
# City not found. Skipping...
# Processing Record 32 of Set 11 | temaraia
# Processing Record 33 of Set 11 | linxia
# Processing Record 34 of Set 11 | comodoro rivadavia
# Processing Record 35 of Set 11 | sulangan
# Processing Record 36 of Set 11 | newport
# Processing Record 37 of Set 11 | tacuati
# Processing Record 38 of Set 11 | orito
# Processing Record 39 of Set 11 | diffa
# Processing Record 40 of Set 11 | tezu
# Processing Record 41 of Set 11 | tamiahua
# Processing Record 42 of Set 11 | kirakira
# Processing Record 43 of Set 11 | fare
# Processing Record 44 of Set 11 | goure
# Processing Record 45 of Set 11 | dogondoutchi
# Processing Record 46 of Set 11 | sampit
# Processing Record 47 of Set 11 | sindor
# Processing Record 48 of Set 11 | suarez
# Processing Record 49 of Set 11 | peniche
# Processing Record 50 of Set 11 | farafangana
# City not found. Skipping...
# Processing Record 1 of Set 12 | pokrovsk-uralskiy
# Processing Record 2 of Set 12 | veraval
# Processing Record 3 of Set 12 | wang saphung
# Processing Record 4 of Set 12 | gravdal
# Processing Record 5 of Set 12 | dalby
# Processing Record 6 of Set 12 | skibbereen
# Processing Record 7 of Set 12 | santo tomas
# City not found. Skipping...
# Processing Record 8 of Set 12 | barawe
# Processing Record 9 of Set 12 | filadelfia
# Processing Record 10 of Set 12 | sabzevar
# Processing Record 11 of Set 12 | ibra
# Processing Record 12 of Set 12 | san cosme y damian
# Processing Record 13 of Set 12 | dhidhdhoo
# Processing Record 14 of Set 12 | corner brook
# Processing Record 15 of Set 12 | olpad
# Processing Record 16 of Set 12 | rongcheng
# Processing Record 17 of Set 12 | copiapo
# Processing Record 18 of Set 12 | pangnirtung
# Processing Record 19 of Set 12 | aksu
# Processing Record 20 of Set 12 | gweta
# Processing Record 21 of Set 12 | bethanien
# Processing Record 22 of Set 12 | tocopilla
# Processing Record 23 of Set 12 | djibo
# Processing Record 24 of Set 12 | codrington
# Processing Record 25 of Set 12 | sandane
# Processing Record 26 of Set 12 | rio brilhante
# Processing Record 27 of Set 12 | maxixe
# Processing Record 28 of Set 12 | casian
# Processing Record 29 of Set 12 | hailar
# Processing Record 30 of Set 12 | batagay
# City not found. Skipping...
# Processing Record 31 of Set 12 | doctor pedro p. pena
# Processing Record 32 of Set 12 | tokur
# Processing Record 33 of Set 12 | reshetylivka
# Processing Record 34 of Set 12 | scarborough
# Processing Record 35 of Set 12 | brewster
# Processing Record 36 of Set 12 | qaqortoq
# Processing Record 37 of Set 12 | leshukonskoye
# Processing Record 38 of Set 12 | sidi ali
# Processing Record 39 of Set 12 | cabra
# Processing Record 40 of Set 12 | andros town
# City not found. Skipping...
# Processing Record 41 of Set 12 | varska
# Processing Record 42 of Set 12 | mount isa
# Processing Record 43 of Set 12 | beaverlodge
# Processing Record 44 of Set 12 | salalah
# Processing Record 45 of Set 12 | misratah
# Processing Record 46 of Set 12 | savonlinna
# Processing Record 47 of Set 12 | pacific grove
# Processing Record 48 of Set 12 | yuxia
# Processing Record 49 of Set 12 | esmeraldas
# City not found. Skipping...
# Processing Record 50 of Set 12 | leh
# City not found. Skipping...
# Processing Record 1 of Set 13 | tyulyachi
# City not found. Skipping...
# Processing Record 2 of Set 13 | bay roberts
# Processing Record 3 of Set 13 | ambon
# Processing Record 4 of Set 13 | ulaanbaatar
# Processing Record 5 of Set 13 | zhigalovo
# Processing Record 6 of Set 13 | flagstaff
# Processing Record 7 of Set 13 | qinhuangdao
# Processing Record 8 of Set 13 | darnah
# Processing Record 9 of Set 13 | calderitas
# Processing Record 10 of Set 13 | sinjai
# Processing Record 11 of Set 13 | oakham
# Processing Record 12 of Set 13 | lodja
# Processing Record 13 of Set 13 | huarmey
# Processing Record 14 of Set 13 | olafsvik
# City not found. Skipping...
# Processing Record 15 of Set 13 | daxian
# Processing Record 16 of Set 13 | hopelchen
# Processing Record 17 of Set 13 | murgab
# Processing Record 18 of Set 13 | dubai
# Processing Record 19 of Set 13 | sola
# City not found. Skipping...
# Processing Record 20 of Set 13 | kytlym
# Processing Record 21 of Set 13 | iquique
# City not found. Skipping...
# Processing Record 22 of Set 13 | ahumada
# Processing Record 23 of Set 13 | cortez
# Processing Record 24 of Set 13 | agirish
# City not found. Skipping...
# Processing Record 25 of Set 13 | ambodifototra
# Processing Record 26 of Set 13 | muhos
# Processing Record 27 of Set 13 | la rioja
# Processing Record 28 of Set 13 | magistralnyy
# Processing Record 29 of Set 13 | flums
# City not found. Skipping...
# Processing Record 30 of Set 13 | hihifo
# Processing Record 31 of Set 13 | toftlund
# City not found. Skipping...
# Processing Record 32 of Set 13 | gangotri
# Processing Record 33 of Set 13 | victoria point
# Processing Record 34 of Set 13 | mayumba
# Processing Record 35 of Set 13 | fairbanks
# Processing Record 36 of Set 13 | vostok
# Processing Record 37 of Set 13 | tahoua
# Processing Record 38 of Set 13 | tres lagoas
# Processing Record 39 of Set 13 | mount gambier
# Processing Record 40 of Set 13 | luanda
# Processing Record 41 of Set 13 | ust-nera
# Processing Record 42 of Set 13 | batangafo
# Processing Record 43 of Set 13 | shubarshi
# Processing Record 44 of Set 13 | zemio
# Processing Record 45 of Set 13 | waitati
# Processing Record 46 of Set 13 | kerema
# Processing Record 47 of Set 13 | kaa-khem
# Processing Record 48 of Set 13 | inirida
# Processing Record 49 of Set 13 | celestun
# Processing Record 50 of Set 13 | mirnyy
# Processing Record 1 of Set 14 | poum
# Processing Record 2 of Set 14 | arkansas city
# Processing Record 3 of Set 14 | abu samrah
# Processing Record 4 of Set 14 | le port
# Processing Record 5 of Set 14 | jalalabad
# City not found. Skipping...
# Processing Record 6 of Set 14 | yirol
# Processing Record 7 of Set 14 | choctaw
# Processing Record 8 of Set 14 | loa janan
# Processing Record 9 of Set 14 | aleksandrov gay
# Processing Record 10 of Set 14 | luwingu
# Processing Record 11 of Set 14 | liwale
# Processing Record 12 of Set 14 | clarence town
# Processing Record 13 of Set 14 | batemans bay
# Processing Record 14 of Set 14 | shakawe
# Processing Record 15 of Set 14 | wloclawek
# Processing Record 16 of Set 14 | vila franca do campo
# Processing Record 17 of Set 14 | mwingi
# Processing Record 18 of Set 14 | keetmanshoop
# Processing Record 19 of Set 14 | paradise
# Processing Record 20 of Set 14 | miri
# Processing Record 21 of Set 14 | egvekinot
# Processing Record 22 of Set 14 | riyadh
# Processing Record 23 of Set 14 | maniitsoq
# Processing Record 24 of Set 14 | gamba
# Processing Record 25 of Set 14 | rio claro
# Processing Record 26 of Set 14 | opuwo
# Processing Record 27 of Set 14 | cape canaveral
# Processing Record 28 of Set 14 | ketchikan
# Processing Record 29 of Set 14 | banyo
# Processing Record 30 of Set 14 | kyra
# Processing Record 31 of Set 14 | mattru
# Processing Record 32 of Set 14 | padina
# Processing Record 33 of Set 14 | nabire
# Processing Record 34 of Set 14 | chifeng
# Processing Record 35 of Set 14 | aasiaat
# Processing Record 36 of Set 14 | yeppoon
# Processing Record 37 of Set 14 | makakilo city
# Processing Record 38 of Set 14 | walvis bay
# Processing Record 39 of Set 14 | chala
# Processing Record 40 of Set 14 | fort dodge
# Processing Record 41 of Set 14 | mana
# Processing Record 42 of Set 14 | horsham
# Processing Record 43 of Set 14 | itupiranga
# Processing Record 44 of Set 14 | dingle
# City not found. Skipping...
# Processing Record 45 of Set 14 | umzimvubu
# Processing Record 46 of Set 14 | brigantine
# Processing Record 47 of Set 14 | berlevag
# Processing Record 48 of Set 14 | macapa
# Processing Record 49 of Set 14 | ayan
# Processing Record 50 of Set 14 | grindavik
# Processing Record 1 of Set 15 | pangkalanbuun
# Processing Record 2 of Set 15 | mecca
# Processing Record 3 of Set 15 | mazyr
# Processing Record 4 of Set 15 | axim
# Processing Record 5 of Set 15 | barra do garcas
# Processing Record 6 of Set 15 | tateyama
# Processing Record 7 of Set 15 | lanzhou
# Processing Record 8 of Set 15 | asosa
# Processing Record 9 of Set 15 | trinidad
# Processing Record 10 of Set 15 | iisalmi
# Processing Record 11 of Set 15 | pathein
# Processing Record 12 of Set 15 | koslan
# Processing Record 13 of Set 15 | wewak
# Processing Record 14 of Set 15 | seoul
# Processing Record 15 of Set 15 | naivasha
# Processing Record 16 of Set 15 | manadhoo
# Processing Record 17 of Set 15 | xuddur
# City not found. Skipping...
# Processing Record 18 of Set 15 | toliary
# Processing Record 19 of Set 15 | awassa
# Processing Record 20 of Set 15 | cananeia
# Processing Record 21 of Set 15 | avera
# Processing Record 22 of Set 15 | beni suef
# Processing Record 23 of Set 15 | youkounkoun
# Processing Record 24 of Set 15 | siloam springs
# Processing Record 25 of Set 15 | sehithwa
# Processing Record 26 of Set 15 | kahului
# Processing Record 27 of Set 15 | dvinskoy
# City not found. Skipping...
# Processing Record 28 of Set 15 | artyk
# Processing Record 29 of Set 15 | havre-saint-pierre
# Processing Record 30 of Set 15 | oros
# Processing Record 31 of Set 15 | tecoanapa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# city_data

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          vaini -21.20 -175.20     73.40        94          90       10.29
# 1         lompoc  34.64 -120.46     60.80        77          90        9.17
# 2     butaritari   3.07  172.79     81.54        69          42        7.36
# 3      ilulissat  69.22  -51.10     17.60        52         100        4.70
# 4          yumen  40.28   97.20     41.40        53          30       15.17
# 5       gangapur  26.48   76.72     79.90        18           0        2.13
# 6  san policarpo  12.18  125.51     82.89        80          94       12.30
# 7   punta arenas -53.15  -70.92     44.60        87          75        2.24
# 8         uarini  -2.99  -65.11     74.07        89          67        1.34
# 9         namibe -15.20   12.15     66.45        85          30        6.29
#
#   Country Current Description
# 0      TO     overcast clouds
# 1      US     overcast clouds
# 2      KI    scattered clouds
# 3      GL     overcast clouds
# 4      CN    scattered clouds
# 5      IN           clear sky
# 6      PH          light rain
# 7      CL       broken clouds
# 8      BR       broken clouds
# 9      AO    scattered clouds

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
#Set Columns
# new_column_order = ["column2", "column4", "column1"]
# df = df[new_column_order]
column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df.reindex(columns=column_order)
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          vaini      TO -21.20 -175.20     73.40        94          90
# 1         lompoc      US  34.64 -120.46     60.80        77          90
# 2     butaritari      KI   3.07  172.79     81.54        69          42
# 3      ilulissat      GL  69.22  -51.10     17.60        52         100
# 4          yumen      CN  40.28   97.20     41.40        53          30
# 5       gangapur      IN  26.48   76.72     79.90        18           0
# 6  san policarpo      PH  12.18  125.51     82.89        80          94
# 7   punta arenas      CL -53.15  -70.92     44.60        87          75
# 8         uarini      BR  -2.99  -65.11     74.07        89          67
# 9         namibe      AO -15.20   12.15     66.45        85          30
#
#    Wind Speed Current Description
# 0       10.29     overcast clouds
# 1        9.17     overcast clouds
# 2        7.36    scattered clouds
# 3        4.70     overcast clouds
# 4       15.17    scattered clouds
# 5        2.13           clear sky
# 6       12.30          light rain
# 7        2.24       broken clouds
# 8        1.34       broken clouds
# 9        6.29    scattered clouds

# %%
city_data_df.head(10)
# Create the output file (CSV).
output_data_file = "/Users/chelseaconrad/Desktop/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
